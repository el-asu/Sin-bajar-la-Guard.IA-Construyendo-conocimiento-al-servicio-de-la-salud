# %% [markdown]
# ## **CAUSAS DE DEFUNCIÓN POR PROVINCIA Y ESPECIALIDADES POR PROVINCIA**
#
# ---

# %% [markdown]
# # **RESUMEN**

# %% [markdown]
# Según estadísticas oficiales del sistema de salud argentino, hay una fuerte carga de enfermedades crónicas no transmisibles, disparidades geográficas en la infraestructura y falta de cobertura médica. Existen distintas fuentes de información disponibles que abordan la situación de la salud argentina, pero lo hacen desde distintos enfoques.

# %% [markdown]
# En este proyecto aplicaremos herramientas de ciencias de datos para integrar datos provenientes de distintas fuentes, para analizar y generar conocimiento sobre la situación actual del sistema de salud en Argentina. Nos enfocaremos en determinar el impacto que tienen las disparidades geográficas en infraestructura y en presencia de especializaciones médicas, sobre indicadores del estado de salud de la población. Buscaremos predecir áreas geográficas y/o sectores socioeconómicos de alta vulnerabilidad, para mejorar la gestión de salud en dichas áreas.

# %% [markdown]
# Este estudio contribuirá al fortalecimiento del sistema de salud argentino al proporcionar información relevante para la toma de decisiones, la asignación eficiente de recursos y la equidad en la atención médica.

# %% [markdown]
# > # **Objetivo:**
#
# **Analizar** y **comprender** la distribución de los establecimientos de salud y las especialidades médicas en todo el país. A partir de este proyecto, se busca generar conocimientos que puedan ser utilizados para mejorar la planificación y la gestión de los recursos de salud a nivel nacional y provincial, así como para identificar posibles áreas de mejora (vulnerabilidad sanitaria).

# %% [markdown]
# # *Hipótesis:*
# Existe una relación entre las causas más recurrentes de muerte por provincia y la disponibilidad de especialidades médicas en esas regiones. Investigar esta relación proporcionará indicadores clave para la planificación efectiva de recursos de salud, identificando las provincias y las especialidades prioritarias.
#
# Puntos a considerar:
#
# * Causas de Muerte: Analizar las causas de muerte más frecuentes en cada provincia, considerando el total de defunciones en relación con la población total.
#
# * Especialidades Médicas: Evaluar si las especialidades médicas disponibles en cada provincia están alineadas con las causas de muerte predominantes.
#
# * Planificación de Recursos: Utilizar esta información para priorizar la asignación de recursos de salud y la capacitación de personal médico en las áreas críticas identificadas.
#
# * Incluir el análisis del total de defunciones respecto a la población total es crucial, ya que proporciona una perspectiva más precisa de la carga de enfermedades y necesidades de salud en cada provincia.

# %% [markdown]
# # **Importar librerias**

# %%
import pandas as pd
import urllib.request
import numpy as np
import requests, zipfile, io
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from io import StringIO
import os

# %% [markdown]
# # **Importar dataframe de causas de defunción para analizar**

# %% [markdown]
# Vamos a trabajar con los datos de:
#
# https://datos.gob.ar/dataset/salud-defunciones-ocurridas-registradas-republica-argentina
#
# Defunciones ocurridas y registradas en la República Argentina entre los años 2005-2022
# Cantidad de defunciones ocurridas y registradas en la República Argentina entre los años 2005-2022

# %%
# URL del archivo CSV
url_csv = 'http://datos.salud.gob.ar/dataset/27c588e8-43d0-411a-a40c-7ecc563c2c9f/resource/ccf688f4-db38-4b0f-86f3-c99341ac52ad/download/defunciones-ocurridas-y-registradas-en-la-republica-argentina-entre-los-anos-2005-2022.csv'

# Descargar el archivo CSV
response = requests.get(url_csv)
with open("defunciones.csv", "wb") as f:
    f.write(response.content)

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv('defunciones.csv')

# Hacer una copia del DataFrame
df2 = df.copy()
# Out:
# <ipython-input-2-5ec492679ecc>:10: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('defunciones.csv')

# %% [markdown]
# # **Análisis del dataframe de causas de defunción**

# %%
#información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825814 entries, 0 to 825813
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   anio                           825814 non-null  int64
#  1   jurisdiccion_de_residencia_id  825814 non-null  int64
#  2   jurisdicion_residencia_nombre  820818 non-null  object
#  3   cie10_causa_id                 825814 non-null  object
#  4   cie10_clasificacion            824103 non-null  object
#  5   sexo_id                        825814 non-null  int64
#  6   Sexo                           825814 non-null  object
#  7   muerte_materna_id              46958 non-null   object
#  8   muerte_materna_clasificacion   4263 non-null    object
#  9   grupo_edad                     825814 non-null  object
#  10  cantidad                       825814 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 69.3+ MB

# %% [markdown]
# * **anio:**
#  * Descripción: Año en el que ocurrieron y se registraron las defunciones.
#  * Tipo de Dato: Entero (int64).
#
# * **jurisdiccion_de_residencia_id:**
#  * Descripción: ID numérico que representa la jurisdicción de residencia del fallecido.
#  * Tipo de Dato: Entero (int64).
#
# * **jurisdicion_residencia_nombre:**
#  * Descripción: Nombre de la jurisdicción de residencia del fallecido.
#  * Tipo de Dato: Cadena de texto (object).
#
# * **cie10_causa_id:**
#  * Descripción: Código de causa de muerte según la Clasificación Internacional de Enfermedades (CIE-10).
#  * Tipo de Dato: Cadena de texto (object).
#
# * **cie10_clasificacion:**
#  * Descripción: Clasificación de la causa de muerte según la CIE-10.
#  * Tipo de Dato: Cadena de texto (object).
#
# * **sexo_id:**
#  * Descripción: ID numérico que representa el sexo del fallecido.
#  * Tipo de Dato: Entero (int64).
#
# * **Sexo:**
#  * Descripción: Sexo del fallecido (por ejemplo, 'Masculino', 'Femenino').
#  * Tipo de Dato: Cadena de texto (object).
#
# * **muerte_materna_id:**
#  * Descripción: ID que indica si la muerte fue materna.
#  * Tipo de Dato: Cadena de texto (object). Tiene muchos valores nulos.
#
# * **muerte_materna_clasificacion:**
#  * Descripción: Clasificación de la muerte materna.
#  * Tipo de Dato: Cadena de texto (object). Tiene muchos valores nulos.
#
# * **grupo_edad:**
#  * Descripción: Grupo de edad del fallecido (por ejemplo, '0-4', '5-9', etc.).
#  * Tipo de Dato: Cadena de texto (object).
#
# * **cantidad:**
#  * Descripción: Número de defunciones registradas.
#  * Tipo de Dato: Entero (int64).

# %%
df.head()
# Out:
#    anio  jurisdiccion_de_residencia_id    jurisdicion_residencia_nombre  \
# 0  2010                             62                        Río Negro
# 1  2013                             90                          Tucumán
# 2  2018                             34                          Formosa
# 3  2020                              6                     Buenos Aires
# 4  2012                              2  Ciudad Autónoma de Buenos Aires
#
#   cie10_causa_id                                cie10_clasificacion  sexo_id  \
# 0            P52  Hemorragia intracraneal no traumática del feto...        2
# 1            R95              Síndrome de la muerte súbita infantil        1
# 2            Q91           Síndrome de Edwards y síndrome  de Patau        2
# 3            Q79  Malformaciones congénitas del sistema osteomus...        2
# 4            B34           Infección viral de sitio no especificado        1
#
#         Sexo muerte_materna_id muerte_materna_clasificacion  \
# 0   femenino               NaN                          NaN
# 1  masculino               NaN                          NaN
# 2   femenino               NaN                          NaN
# 3   femenino               NaN                          NaN
# 4  masculino               NaN                          NaN
#
#               grupo_edad  cantidad
# 0  01.De a 0  a 14 anios         1
# 1  01.De a 0  a 14 anios         5
# 2  01.De a 0  a 14 anios         1
# 3  01.De a 0  a 14 anios         3
# 4  01.De a 0  a 14 anios         1

# %%
# Quiero conocer las jurisdicciones de residencia
df.jurisdicion_residencia_nombre.unique()
# Out:
# array(['Río Negro', 'Tucumán', 'Formosa', 'Buenos Aires',
#        'Ciudad Autónoma de Buenos Aires', 'Sin Información', 'Santa Fe',
#        'Misiones', 'San Juan', 'Entre Ríos', 'Corrientes', 'Chubut',
#        'La Pampa', 'Neuquén', 'Catamarca',
#        'Tierra del Fuego, Antártida e Islas del Atlántico Sur',
#        'Santa Cruz', 'Mendoza', 'Córdoba', 'Jujuy', 'Chaco',
#        'Santiago del Estero', 'Salta', 'La Rioja', 'San Luis', nan],
#       dtype=object)

# %%
print(df.isnull().sum())
# Out:
# anio                                  0
# jurisdiccion_de_residencia_id         0
# jurisdicion_residencia_nombre      4996
# cie10_causa_id                        0
# cie10_clasificacion                1711
# sexo_id                               0
# Sexo                                  0
# muerte_materna_id                778856
# muerte_materna_clasificacion     821551
# grupo_edad                            0
# cantidad                              0
# dtype: int64

# %% [markdown]
# Vamos a eliminar los atributos que tienen más datos faltantes, muerte_materna_id y muerte_materna_clasificacion

# %%
# Eliminar filas con valores nulos en columnas críticas
df_clean = df.dropna(subset=['jurisdicion_residencia_nombre', 'cie10_clasificacion'])

# Manejar valores nulos en otras columnas
df_clean['muerte_materna_id'] = df_clean['muerte_materna_id'].fillna('Desconocido')
df_clean['muerte_materna_clasificacion'] = df_clean['muerte_materna_clasificacion'].fillna('Desconocido')

# Eliminar duplicados
df_clean = df_clean.drop_duplicates()

# Verificar la información del DataFrame limpio
print(df_clean.info())

# Verificar los valores nulos
print(df_clean.isnull().sum())

# Análisis exploratorio de datos (EDA)

# Distribución por año
df_clean['anio'].value_counts().sort_index().plot(kind='bar', figsize=(12, 6))
plt.xlabel('Año')
plt.ylabel('Número de Defunciones')
plt.title('Distribución de Defunciones por Año')
plt.show()

# Distribución por sexo
df_clean['Sexo'].value_counts().plot(kind='bar', figsize=(8, 6))
plt.xlabel('Sexo')
plt.ylabel('Número de Defunciones')
plt.title('Distribución de Defunciones por Sexo')
plt.show()

# Distribución por grupo de edad
df_clean['grupo_edad'].value_counts().sort_index().plot(kind='bar', figsize=(12, 6))
plt.xlabel('Grupo de Edad')
plt.ylabel('Número de Defunciones')
plt.title('Distribución de Defunciones por Grupo de Edad')
plt.show()

# Relación entre causa de muerte y sexo
sns.countplot(x='cie10_clasificacion', hue='Sexo', data=df_clean, order=df_clean['cie10_clasificacion'].value_counts().index[:10])
plt.xticks(rotation=90)
plt.xlabel('Causa de Muerte')
plt.ylabel('Número de Defunciones')
plt.title('Distribución de Defunciones por Causa de Muerte y Sexo')
plt.show()
# Out:
# <ipython-input-7-ed36faa67ee7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['muerte_materna_id'] = df_clean['muerte_materna_id'].fillna('Desconocido')
# <ipython-input-7-ed36faa67ee7>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['muerte_materna_clasificacion'] = df_clean['muerte_materna_clasificacion'].fillna('Desconocido')
# <class 'pandas.core.frame.DataFrame'>
# Index: 697575 entries, 0 to 825813
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   anio                           697575 non-null  int64
#  1   jurisdiccion_de_residencia_id  697575 non-null  int64
#  2   jurisdicion_residencia_nombre  697575 non-null  object
#  3   cie10_causa_id                 697575 non-null  object
#  4   cie10_clasificacion            697575 non-null  object
#  5   sexo_id                        697575 non-null  int64
#  6   Sexo                           697575 non-null  object
#  7   muerte_materna_id              697575 non-null  object
#  8   muerte_materna_clasificacion   697575 non-null  object
#  9   grupo_edad                     697575 non-null  object
#  10  cantidad                       697575 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 63.9+ MB
# None
# anio                             0
# jurisdiccion_de_residencia_id    0
# jurisdicion_residencia_nombre    0
# cie10_causa_id                   0
# cie10_clasificacion              0
# sexo_id                          0
# Sexo                             0
# muerte_materna_id                0
# muerte_materna_clasificacion     0
# grupo_edad                       0
# cantidad                         0
# dtype: int64

# %%
df_clean['jurisdicion_residencia_nombre'].unique()
# Out:
# array(['Río Negro', 'Tucumán', 'Formosa', 'Buenos Aires',
#        'Ciudad Autónoma de Buenos Aires', 'Sin Información', 'Santa Fe',
#        'Misiones', 'San Juan', 'Entre Ríos', 'Corrientes', 'Chubut',
#        'La Pampa', 'Neuquén', 'Catamarca',
#        'Tierra del Fuego, Antártida e Islas del Atlántico Sur',
#        'Santa Cruz', 'Mendoza', 'Córdoba', 'Jujuy', 'Chaco',
#        'Santiago del Estero', 'Salta', 'La Rioja', 'San Luis'],
#       dtype=object)

# %%
df_clean['cie10_clasificacion'].unique()
# Out:
# array(['Hemorragia intracraneal no traumática del feto y del recién nacido',
#        'Síndrome de la muerte súbita infantil',
#        'Síndrome de Edwards y síndrome  de Patau', ...,
#        'Trastornos delirantes persistentes',
#        'Hallazgo de drogas y otras sustancias que normalmente no se encuentran en la sangre',
#        'Medicamentos o sustancias biológicas contaminados'], dtype=object)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 697575 entries, 0 to 825813
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   anio                           697575 non-null  int64
#  1   jurisdiccion_de_residencia_id  697575 non-null  int64
#  2   jurisdicion_residencia_nombre  697575 non-null  object
#  3   cie10_causa_id                 697575 non-null  object
#  4   cie10_clasificacion            697575 non-null  object
#  5   sexo_id                        697575 non-null  int64
#  6   Sexo                           697575 non-null  object
#  7   muerte_materna_id              697575 non-null  object
#  8   muerte_materna_clasificacion   697575 non-null  object
#  9   grupo_edad                     697575 non-null  object
#  10  cantidad                       697575 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 63.9+ MB

# %%
# Select only numeric columns
numeric_columns = df_clean.select_dtypes(include=['float64', 'int64'])

# Create a correlation matrix
correlation_matrix = numeric_columns.corr()

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='magma', fmt=".2f")
plt.show()

# %%
df_clean['anio'].unique()
# Out:
# array([2010, 2013, 2018, 2020, 2012, 2009, 2017, 2019, 2016, 2021, 2011,
#        2007, 2006, 2015, 2022, 2014, 2008, 2005])

# %% [markdown]
# Vamos a quedarnos con los datos de 2019 y 2020

# %%
filtered_df = df_clean[(df_clean['anio'] >= 2019) & (df_clean['anio'] <= 2019)]

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40242 entries, 8 to 825793
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   anio                           40242 non-null  int64
#  1   jurisdiccion_de_residencia_id  40242 non-null  int64
#  2   jurisdicion_residencia_nombre  40242 non-null  object
#  3   cie10_causa_id                 40242 non-null  object
#  4   cie10_clasificacion            40242 non-null  object
#  5   sexo_id                        40242 non-null  int64
#  6   Sexo                           40242 non-null  object
#  7   muerte_materna_id              40242 non-null  object
#  8   muerte_materna_clasificacion   40242 non-null  object
#  9   grupo_edad                     40242 non-null  object
#  10  cantidad                       40242 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 3.7+ MB

# %%
filtered_df['jurisdicion_residencia_nombre'].unique()
# Out:
# array(['San Juan', 'Buenos Aires', 'Santa Fe', 'Jujuy', 'La Rioja',
#        'Córdoba', 'Chaco', 'Misiones', 'Corrientes', 'Santa Cruz',
#        'San Luis', 'Neuquén', 'Santiago del Estero', 'Salta', 'Catamarca',
#        'La Pampa', 'Mendoza', 'Tucumán', 'Formosa',
#        'Ciudad Autónoma de Buenos Aires', 'Entre Ríos', 'Chubut',
#        'Río Negro', 'Sin Información',
#        'Tierra del Fuego, Antártida e Islas del Atlántico Sur'],
#       dtype=object)

# %%
# Se eliminan las filas con el valor "Sin Información" en la columna referida al nombre de la jurisdicción
df2 = filtered_df.loc[filtered_df['jurisdicion_residencia_nombre'] != "Sin Información"]

# %%
# Verificación que sólo queden las filas con el nombre de las provincias correctamente definido
df2['jurisdicion_residencia_nombre'].unique()
# Out:
# array(['San Juan', 'Buenos Aires', 'Santa Fe', 'Jujuy', 'La Rioja',
#        'Córdoba', 'Chaco', 'Misiones', 'Corrientes', 'Santa Cruz',
#        'San Luis', 'Neuquén', 'Santiago del Estero', 'Salta', 'Catamarca',
#        'La Pampa', 'Mendoza', 'Tucumán', 'Formosa',
#        'Ciudad Autónoma de Buenos Aires', 'Entre Ríos', 'Chubut',
#        'Río Negro',
#        'Tierra del Fuego, Antártida e Islas del Atlántico Sur'],
#       dtype=object)

# %%
# Verificación que no queden filas en el dataframe con valor NaN en la columna referida al nombre de la jurisdicción
df2[df2['jurisdicion_residencia_nombre'].isnull()]
# Out:
# Empty DataFrame
# Columns: [anio, jurisdiccion_de_residencia_id, jurisdicion_residencia_nombre, cie10_causa_id, cie10_clasificacion, sexo_id, Sexo, muerte_materna_id, muerte_materna_clasificacion, grupo_edad, cantidad]
# Index: []

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39692 entries, 8 to 825782
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   anio                           39692 non-null  int64
#  1   jurisdiccion_de_residencia_id  39692 non-null  int64
#  2   jurisdicion_residencia_nombre  39692 non-null  object
#  3   cie10_causa_id                 39692 non-null  object
#  4   cie10_clasificacion            39692 non-null  object
#  5   sexo_id                        39692 non-null  int64
#  6   Sexo                           39692 non-null  object
#  7   muerte_materna_id              39692 non-null  object
#  8   muerte_materna_clasificacion   39692 non-null  object
#  9   grupo_edad                     39692 non-null  object
#  10  cantidad                       39692 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 3.6+ MB

# %%
# Distribución de muertes por jurisdicción
plt.figure(figsize=(12, 8))
sns.countplot(data=df2, y='jurisdicion_residencia_nombre', palette='magma', order=df2['jurisdicion_residencia_nombre'].value_counts().index)
plt.xlabel('Número de Defunciones')
plt.ylabel('Jurisdicción de Residencia')
plt.title('Distribución de Defunciones por Jurisdicción de Residencia')
plt.show()
# Out:
# <ipython-input-20-7b6f8c3e868b>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df2, y='jurisdicion_residencia_nombre', palette='magma', order=df2['jurisdicion_residencia_nombre'].value_counts().index)

# %%
# Sumar la cantidad de muertes por jurisdicción
df_jur_cantidad = df2.groupby('jurisdicion_residencia_nombre')['cantidad'].sum().reset_index()

# Graficar la cantidad de muertes por jurisdicción
plt.figure(figsize=(12, 8))
sns.barplot(data=df_jur_cantidad, y='jurisdicion_residencia_nombre', x='cantidad', palette='magma', order=df_jur_cantidad.sort_values('cantidad', ascending=False)['jurisdicion_residencia_nombre'])
plt.xlabel('Cantidad de Defunciones')
plt.ylabel('Jurisdicción de Residencia')
plt.title('Cantidad de Defunciones por Jurisdicción de Residencia')
plt.show()
# Out:
# <ipython-input-21-677ad116289a>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_jur_cantidad, y='jurisdicion_residencia_nombre', x='cantidad', palette='magma', order=df_jur_cantidad.sort_values('cantidad', ascending=False)['jurisdicion_residencia_nombre'])

# %%
# Crear la tabla de contingencia
crosstab_jur_causa = pd.crosstab(df2['jurisdicion_residencia_nombre'], df2['cie10_clasificacion'])

# %%
# Mostrar las primeras 10 filas y columnas de la tabla de contingencia
print(crosstab_jur_causa.iloc[:10, :10])
# Out:
# cie10_clasificacion              Aborto espontáneo  Aborto médico  \
# jurisdicion_residencia_nombre
# Buenos Aires                                     0              0
# Catamarca                                        0              0
# Chaco                                            0              0
# Chubut                                           0              0
# Ciudad Autónoma de Buenos Aires                  0              1
# Corrientes                                       0              0
# Córdoba                                          0              0
# Entre Ríos                                       0              0
# Formosa                                          0              0
# Jujuy                                            0              0
#
# cie10_clasificacion              Aborto no especificado  \
# jurisdicion_residencia_nombre
# Buenos Aires                                          0
# Catamarca                                             0
# Chaco                                                 0
# Chubut                                                0
# Ciudad Autónoma de Buenos Aires                       0
# Corrientes                                            0
# Córdoba                                               0
# Entre Ríos                                            0
# Formosa                                               0
# Jujuy                                                 0
#
# cie10_clasificacion              Absceso cutáneo, furúnculo y ántrax  \
# jurisdicion_residencia_nombre
# Buenos Aires                                                       9
# Catamarca                                                          1
# Chaco                                                              2
# Chubut                                                             2
# Ciudad Autónoma de Buenos Aires                                    2
# Corrientes                                                         0
# Córdoba                                                            0
# Entre Ríos                                                         2
# Formosa                                                            1
# Jujuy                                                              3
#
# cie10_clasificacion              Absceso de las regiones anal y rectal  \
# jurisdicion_residencia_nombre
# Buenos Aires                                                         0
# Catamarca                                                            0
# Chaco                                                                0
# Chubut                                                               1
# Ciudad Autónoma de Buenos Aires                                      0
# Corrientes                                                           0
# Córdoba                                                              0
# Entre Ríos                                                           1
# Formosa                                                              1
# Jujuy                                                                0
#
# cie10_clasificacion              Absceso del pulmón y del mediastino  \
# jurisdicion_residencia_nombre
# Buenos Aires                                                       8
# Catamarca                                                          0
# Chaco                                                              0
# Chubut                                                             0
# Ciudad Autónoma de Buenos Aires                                    4
# Corrientes                                                         1
# Córdoba                                                            2
# Entre Ríos                                                         2
# Formosa                                                            0
# Jujuy                                                              1
#
# cie10_clasificacion              Absceso periamigdalino  \
# jurisdicion_residencia_nombre
# Buenos Aires                                          0
# Catamarca                                             0
# Chaco                                                 0
# Chubut                                                0
# Ciudad Autónoma de Buenos Aires                       0
# Corrientes                                            0
# Córdoba                                               1
# Entre Ríos                                            0
# Formosa                                               0
# Jujuy                                                 0
#
# cie10_clasificacion              Absceso y granuloma intracraneal e intrarraquídeo  \
# jurisdicion_residencia_nombre
# Buenos Aires                                                                     9
# Catamarca                                                                        0
# Chaco                                                                            0
# Chubut                                                                           0
# Ciudad Autónoma de Buenos Aires                                                  1
# Corrientes                                                                       1
# Córdoba                                                                          2
# Entre Ríos                                                                       0
# Formosa                                                                          1
# Jujuy                                                                            0
#
# cie10_clasificacion              Accidente de aeronave de motor, con ocupante lesionado  \
# jurisdicion_residencia_nombre
# Buenos Aires                                                                     0
# Catamarca                                                                        0
# Chaco                                                                            1
# Chubut                                                                           0
# Ciudad Autónoma de Buenos Aires                                                  1
# Corrientes                                                                       0
# Córdoba                                                                          1
# Entre Ríos                                                                       0
# Formosa                                                                          0
# Jujuy                                                                            0
#
# cie10_clasificacion              Accidente de aeronave sin motor, con ocupante lesionado
# jurisdicion_residencia_nombre
# Buenos Aires                                                                     1
# Catamarca                                                                        0
# Chaco                                                                            0
# Chubut                                                                           0
# Ciudad Autónoma de Buenos Aires                                                  0
# Corrientes                                                                       0
# Córdoba                                                                          0
# Entre Ríos                                                                       0
# Formosa                                                                          0
# Jujuy                                                                            0

# %% [markdown]
# # **Dataframe población por provincia**

# %% [markdown]
# Datos de población por provincia estimados po INDEC a partir de los censos anteriores:
#
# https://sitioanterior.indec.gob.ar/nivel4_default.asp?id_tema_1=2&id_tema_2=24&id_tema_3=85
#
# Datos:
# Población estimada al 1 de julio según año calendario por sexo para el total del país y provincias. Años 2010-2040.
#
# La presente publicación describe el proceso a través del cual se elaboraron las proyecciones
# de población de las provincias que componen la República Argentina, así como también se presentan los principales resultados.
#
#
# Proyecciones provinciales de población
# por sexo y grupo de edad 2010-2040
# Nos quedamos con los datos del 2019
#
# buenos aires 2019 17.370.144
#
# caba 2019 3.072.029
#
# catamarca 2019 411.824
#
# chaco 2019 1.192.616
#
# chubut 2019 608.729
#
# cordoba 2019 3.722.332
#
# corrientes 2019 1.111.052
#
# entre rios 2019 1.373.270
#
# formosa 2019 600.229
#
# jujuy 2019 762.440
#
# la pampa 2019 355.422
#
# la rioja 2019 388.386
#
# mendoza 2019 1.969.982
#
# misiones 2019 1.247.362
#
# neuquen 2019 655.501
#
# rio negro 2019 738.060
#
# salta 2019 1.406.584
#
# san juan 2019 772.876
#
# san luis 2019 502.000
#
# santa cruz 2019 356.647
#
# santa fe 2019 3.509.113
#
# santiago del estero 2019 968.309
#
# tierra del fuego 2019 169.183
#
# tucuman 2019 1.674.622

# %%
# Crear listas con los datos de las provincias y la cantidad de habitantes en 2020
provincias = [
    'Buenos Aires', 'CABA', 'Catamarca', 'Chaco', 'Chubut', 'Córdoba', 'Corrientes',
    'Entre Ríos', 'Formosa', 'Jujuy', 'La Pampa', 'La Rioja', 'Mendoza', 'Misiones',
    'Neuquén', 'Río Negro', 'Salta', 'San Juan', 'San Luis', 'Santa Cruz', 'Santa Fe',
    'Santiago del Estero', 'Tierra del Fuego', 'Tucumán'
]


habitantes_2019 = [
    17370144, 3072029, 411824, 1192616, 608729, 3722332, 1111052, 1373270,
    600229, 762440, 355422, 388386, 1969982, 1247362, 655501, 738060,
    1406584, 772876, 502000, 356647, 3509113, 968309, 169183, 1674622
]


# Crear un diccionario con los datos
data = {
    'Provincia': provincias,
    'Población 2019': habitantes_2019
}

# Crear el DataFrame
df_poblacion = pd.DataFrame(data)

# Mostrar el DataFrame resultante
print("DataFrame df_poblacion:")
print(df_poblacion)
# Out:
# DataFrame df_poblacion:
#               Provincia  Población 2019
# 0          Buenos Aires        17370144
# 1                  CABA         3072029
# 2             Catamarca          411824
# 3                 Chaco         1192616
# 4                Chubut          608729
# 5               Córdoba         3722332
# 6            Corrientes         1111052
# 7            Entre Ríos         1373270
# 8               Formosa          600229
# 9                 Jujuy          762440
# 10             La Pampa          355422
# 11             La Rioja          388386
# 12              Mendoza         1969982
# 13             Misiones         1247362
# 14              Neuquén          655501
# 15            Río Negro          738060
# 16                Salta         1406584
# 17             San Juan          772876
# 18             San Luis          502000
# 19           Santa Cruz          356647
# 20             Santa Fe         3509113
# 21  Santiago del Estero          968309
# 22     Tierra del Fuego          169183
# 23              Tucumán         1674622

# %%
# Cambiar nombres de provincias a mayúsculas
df_poblacion['Provincia'] = df_poblacion['Provincia'].str.upper()

# %%
# Cambiar 'TIERRA DEL FUEGO' a 'TIERRA DEL FUEGO, ANTÁRTIDA E ISLAS DEL ATLÁNTICO SUR'
df_poblacion.loc[df_poblacion['Provincia'] == 'TIERRA DEL FUEGO', 'Provincia'] = 'TIERRA DEL FUEGO, ANTÁRTIDA E ISLAS DEL ATLÁNTICO SUR'

# %%
# Ordenar de forma descendente por Población 2020
df_poblacion = df_poblacion.sort_values(by='Población 2019', ascending=False)

# Mostrar el DataFrame ordenado
print(df_poblacion)
# Out:
#                                             Provincia  Población 2019
# 0                                        BUENOS AIRES        17370144
# 5                                             CÓRDOBA         3722332
# 20                                           SANTA FE         3509113
# 1                                                CABA         3072029
# 12                                            MENDOZA         1969982
# 23                                            TUCUMÁN         1674622
# 16                                              SALTA         1406584
# 7                                          ENTRE RÍOS         1373270
# 13                                           MISIONES         1247362
# 3                                               CHACO         1192616
# 6                                          CORRIENTES         1111052
# 21                                SANTIAGO DEL ESTERO          968309
# 17                                           SAN JUAN          772876
# 9                                               JUJUY          762440
# 15                                          RÍO NEGRO          738060
# 14                                            NEUQUÉN          655501
# 4                                              CHUBUT          608729
# 8                                             FORMOSA          600229
# 18                                           SAN LUIS          502000
# 2                                           CATAMARCA          411824
# 11                                           LA RIOJA          388386
# 19                                         SANTA CRUZ          356647
# 10                                           LA PAMPA          355422
# 22  TIERRA DEL FUEGO, ANTÁRTIDA E ISLAS DEL ATLÁNT...          169183

# %% [markdown]
# # **Data frame de especialidades por provincia**

# %% [markdown]
# Vamos a crear el df de especialidades para luego unir los dataframes.

# %%
# URLs de los archivos CSV en el repositorio
csv_urls = [
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_bsas.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_cba.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_caba.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_mendoza.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_santafe.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_catamarca.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_formosa.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_entrerios.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_corrientes.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_jujuy.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_larioja.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_neuquen.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_rionegro.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_salta.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_sanluis.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_tierradelfuego.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_tucuman.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_chaco.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_lapampa.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_santacruz.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_chubut.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_sanjuan.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_misiones.csv',
    'https://raw.githubusercontent.com/JuliMarquez/Sin-bajar-la-Guard.IA/main/datasets/esp_santiagodelestero.csv'
]

# Función para cargar CSV desde URL y asignar nombre al DataFrame
def cargar_csv_desde_url(url):
    file_name = os.path.basename(url)  # Obtener el nombre del archivo desde la URL
    response = requests.get(url)
    if response.status_code == 200:
        df = pd.read_csv(StringIO(response.text))
        return df, file_name
    else:
        print(f'Error al cargar CSV desde {url}. Código de estado:', response.status_code)
        return None, None

# Cargar cada archivo CSV en un DataFrame y asignar nombres
dfs = []
names = []
for url in csv_urls:
    df, name = cargar_csv_desde_url(url)
    if df is not None:
        dfs.append(df)
        names.append(name)

# Mostrar información de cada DataFrame cargado
for name, df in zip(names, dfs):
    print(f'Información del DataFrame "{name}":')
    print(df.info())  # Mostrar información del DataFrame
    print()  # Agregar línea en blanco entre DataFrames
# Out:
# Información del DataFrame "esp_bsas.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        80 non-null     object
#  1   Suma de Cantidad    80 non-null     int64
#  2   Suma de Porcentaje  80 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.0+ KB
# None
#
# Información del DataFrame "esp_cba.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        71 non-null     object
#  1   Suma de Cantidad    71 non-null     int64
#  2   Suma de Porcentaje  71 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.8+ KB
# None
#
# Información del DataFrame "esp_caba.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        80 non-null     object
#  1   Suma de Cantidad    80 non-null     int64
#  2   Suma de Porcentaje  80 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.0+ KB
# None
#
# Información del DataFrame "esp_mendoza.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        72 non-null     object
#  1   Suma de Cantidad    72 non-null     int64
#  2   Suma de Porcentaje  72 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.8+ KB
# None
#
# Información del DataFrame "esp_santafe.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        68 non-null     object
#  1   Suma de Cantidad    68 non-null     int64
#  2   Suma de Porcentaje  68 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ KB
# None
#
# Información del DataFrame "esp_catamarca.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        43 non-null     object
#  1   Suma de Cantidad    43 non-null     int64
#  2   Suma de Porcentaje  43 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.1+ KB
# None
#
# Información del DataFrame "esp_formosa.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        46 non-null     object
#  1   Suma de Cantidad    46 non-null     int64
#  2   Suma de Porcentaje  46 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.2+ KB
# None
#
# Información del DataFrame "esp_entrerios.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        67 non-null     object
#  1   Suma de Cantidad    67 non-null     int64
#  2   Suma de Porcentaje  67 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ KB
# None
#
# Información del DataFrame "esp_corrientes.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        59 non-null     object
#  1   Suma de Cantidad    59 non-null     int64
#  2   Suma de Porcentaje  59 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.5+ KB
# None
#
# Información del DataFrame "esp_jujuy.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        61 non-null     object
#  1   Suma de Cantidad    61 non-null     int64
#  2   Suma de Porcentaje  61 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.6+ KB
# None
#
# Información del DataFrame "esp_larioja.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        53 non-null     object
#  1   Suma de Cantidad    53 non-null     int64
#  2   Suma de Porcentaje  53 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.4+ KB
# None
#
# Información del DataFrame "esp_neuquen.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        66 non-null     object
#  1   Suma de Cantidad    66 non-null     int64
#  2   Suma de Porcentaje  66 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ KB
# None
#
# Información del DataFrame "esp_rionegro.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        65 non-null     object
#  1   Suma de Cantidad    65 non-null     int64
#  2   Suma de Porcentaje  65 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.6+ KB
# None
#
# Información del DataFrame "esp_salta.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        64 non-null     object
#  1   Suma de Cantidad    64 non-null     int64
#  2   Suma de Porcentaje  64 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.6+ KB
# None
#
# Información del DataFrame "esp_sanluis.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        54 non-null     object
#  1   Suma de Cantidad    54 non-null     int64
#  2   Suma de Porcentaje  54 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.4+ KB
# None
#
# Información del DataFrame "esp_tierradelfuego.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        55 non-null     object
#  1   Suma de Cantidad    55 non-null     int64
#  2   Suma de Porcentaje  55 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.4+ KB
# None
#
# Información del DataFrame "esp_tucuman.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        64 non-null     object
#  1   Suma de Cantidad    64 non-null     int64
#  2   Suma de Porcentaje  64 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.6+ KB
# None
#
# Información del DataFrame "esp_chaco.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        58 non-null     object
#  1   Suma de Cantidad    58 non-null     int64
#  2   Suma de Porcentaje  58 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.5+ KB
# None
#
# Información del DataFrame "esp_lapampa.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        62 non-null     object
#  1   Suma de Cantidad    62 non-null     int64
#  2   Suma de Porcentaje  62 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.6+ KB
# None
#
# Información del DataFrame "esp_santacruz.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        48 non-null     object
#  1   Suma de Cantidad    48 non-null     int64
#  2   Suma de Porcentaje  48 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.2+ KB
# None
#
# Información del DataFrame "esp_chubut.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        63 non-null     object
#  1   Suma de Cantidad    63 non-null     int64
#  2   Suma de Porcentaje  63 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.6+ KB
# None
#
# Información del DataFrame "esp_sanjuan.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        67 non-null     object
#  1   Suma de Cantidad    67 non-null     int64
#  2   Suma de Porcentaje  67 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ KB
# None
#
# Información del DataFrame "esp_misiones.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        58 non-null     object
#  1   Suma de Cantidad    58 non-null     int64
#  2   Suma de Porcentaje  58 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.5+ KB
# None
#
# Información del DataFrame "esp_santiagodelestero.csv":
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Especialidad        53 non-null     object
#  1   Suma de Cantidad    53 non-null     int64
#  2   Suma de Porcentaje  53 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.4+ KB
# None

# %%
# Crear el DataFrame final df_especialidad combinando todos los DataFrames
df_especialidad = None

for df_name, df in zip(names, dfs):
    # Renombrar la columna 'Suma de Cantidad' a nombre de la provincia
    df.rename(columns={'Suma de Cantidad': df_name.replace('.csv', '')}, inplace=True)
    # Seleccionar solo las columnas relevantes para el DataFrame final
    df = df[['Especialidad', df_name.replace('.csv', '')]]
    # Si df_especialidad no ha sido inicializado, inicializarlo con el primer DataFrame
    if df_especialidad is None:
        df_especialidad = df.copy()
    else:
        # Combinar el DataFrame actual con df_especialidad usando la columna 'Especialidad' como índice
        df_especialidad = pd.merge(df_especialidad, df, on='Especialidad', how='outer')

# Mostrar información del DataFrame final
print('Información del DataFrame final df_especialidad:')
print(df_especialidad.info())
# Out:
# Información del DataFrame final df_especialidad:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Especialidad           104 non-null    object
#  1   esp_bsas               80 non-null     float64
#  2   esp_cba                71 non-null     float64
#  3   esp_caba               80 non-null     float64
#  4   esp_mendoza            72 non-null     float64
#  5   esp_santafe            68 non-null     float64
#  6   esp_catamarca          43 non-null     float64
#  7   esp_formosa            46 non-null     float64
#  8   esp_entrerios          67 non-null     float64
#  9   esp_corrientes         59 non-null     float64
#  10  esp_jujuy              61 non-null     float64
#  11  esp_larioja            53 non-null     float64
#  12  esp_neuquen            66 non-null     float64
#  13  esp_rionegro           65 non-null     float64
#  14  esp_salta              64 non-null     float64
#  15  esp_sanluis            54 non-null     float64
#  16  esp_tierradelfuego     55 non-null     float64
#  17  esp_tucuman            64 non-null     float64
#  18  esp_chaco              58 non-null     float64
#  19  esp_lapampa            62 non-null     float64
#  20  esp_santacruz          48 non-null     float64
#  21  esp_chubut             63 non-null     float64
#  22  esp_sanjuan            67 non-null     float64
#  23  esp_misiones           58 non-null     float64
#  24  esp_santiagodelestero  53 non-null     float64
# dtypes: float64(24), object(1)
# memory usage: 20.4+ KB
# None

# %%
df_especialidad['Especialidad'].unique()
# Out:
# array(['Alergia e Inmunología', 'Alergia e inmunología Pediátrica',
#        'Anatomía Patológica', 'Anestesiología',
#        'Angiología General y Hemodinamia',
#        'Auditoría de Servicios de Salud', 'Cardiología',
#        'Cardiología Infantil', 'Cirugía Cardiovascular',
#        'Cirugía Cardiovascular Pediátric', 'Cirugía de Cabeza y Cuello',
#        'Cirugía de Tórax (Cirugía Torácica)', 'Cirugía General',
#        'Cirugía infantil (Cirugía Pediátric',
#        'Cirugía Plástica y Reparadora', 'Cirugía Vascular Periférica',
#        'Clínica Médica', 'Coloproctología', 'Dermatología',
#        'Dermatología Pediátrica', 'Diagnóstico por Imágenes',
#        'Emergentología', 'Endocrinología', 'Endocrinología Infantil',
#        'Enfermería en Cuidados Paliativos',
#        'Enfermería en Salud del Adulto', 'Epidemiología',
#        'Especialidad de Endodoncia',
#        'Especialidad en Cirugía y Traumatología Bucomaxilofacial',
#        'Farmacología Clínica',
#        'Fisiatría (Medicina Física y Rehabilitación)',
#        'Gastroenterología', 'Gastroenterología Infantil',
#        'Genética Médica', 'Geriatría', 'Gestión de Servicios de Salud',
#        'Ginecología', 'Hematología', 'Hematología Infantil',
#        'Hemato-oncología Pediátrica', 'Hemoterapia e Inmunohema',
#        'Hepatología', 'Hepatología Pediátrica', 'Infectología',
#        'Infectología Infantil', 'MASTOLOGÍA (R)', 'Medicina del Deporte',
#        'Medicina del Trabajo',
#        'Medicina General y/o Medicina de\nFamilia', 'Medicina Legal',
#        'Medicina Nuclear', 'Medicina Paliativa', 'Nefrología',
#        'Nefrología Infantil', 'Neonatología', 'Neumonología',
#        'Neumonología Infantil', 'Neurocirugía', 'Neurología',
#        'Neurología Infantil', 'Nutrición', 'Obstetricia', 'Oftalmología',
#        'Oncología', 'Oncología Infantil', 'Ortopedia y Traumatología',
#        'Ortopedia y Traumatología Infan', 'Otorrinolaringología',
#        'Pediatría', 'Psiquiatría', 'Psiquiatría Infanto Juvenil',
#        'Radioterapia o Terapia Radiante', 'Reumatología',
#        'Reumatología Infantil', 'Salud Pública', 'Terapia Intensiva',
#        'Terapia Intensiva Infantil', 'Tocoginecología', 'Toxicología',
#        'Urología', 'Cirugía infantil (Cirugía Pediátrica)',
#        'Electrofisiología cardíaca', 'Fisiatría (Medicina Física y',
#        'Hemoterapia e Inmunohematología',
#        'Medicina General y/o Medicina de Familia',
#        'Ortopedia y Traumatología Infantil', 'Radiología (R)',
#        'Angiología General y Hemodina', 'Cirugía de Tórax (Cirugía Torá',
#        'Cirugía infantil (Cirugía Pediá',
#        'Enfermería en Cuidados Paliativ', 'Medicina General y/o Medicina',
#        'Cirugía Cardiovascular Pediátrica',
#        'Especialidad de Odontopediatría',
#        'Especialidad en Cirugía y\nTraumatología Bucomaxilofacial',
#        'Medicina General y/o Medicina Familia',
#        'Auditoría de Servicios de Sal',
#        'Enfermería en Salud Mental y Psiquiatría',
#        'Hemoterapia e Inmunohematol',
#        'Enfermería en Salud Mental Psiquiatría',
#        'Fisiatría (Medicina Física y Familia',
#        'Medicina General y/o Medicina\nFamilia',
#        'Cirugía de Tórax (Cirugía Torácic', 'Salud Mental (R)'],
#       dtype=object)

# %%
# Diccionario de corrección de especialidades
corrections = {
    'Alergia e inmunología Pediátrica': 'Alergia e Inmunología Pediátrica',
    'Cirugía infantil (Cirugía Pediátric': 'Cirugía Infantil (Cirugía Pediátrica)',
    'Fisiatría (Medicina Física y': 'Fisiatría (Medicina Física y Rehabilitación)',
    'Hemoterapia e Inmunohematol': 'Hemoterapia e Inmunohematología',
    'MASTOLOGÍA (R)': 'Mastología',
    'Medicina General y/o Medicina': 'Medicina General y/o Medicina de Familia',
    'Ortopedia y Traumatología Infantil': 'Ortopedia y Traumatología Infantil',
    'Radiología (R)': 'Radioterapia o Terapia Radiante',
    'Angiología General y Hemodina': 'Angiología General y Hemodinamia',
    'Cirugía de Tórax (Cirugía Torá': 'Cirugía de Tórax (Cirugía Torácica)',
    'Enfermería en Cuidados Paliativ': 'Enfermería en Cuidados Paliativos',
    'Medicina General y/o Medicina': 'Medicina General y/o Medicina de Familia',
    'Auditoría de Servicios de Sal': 'Auditoría de Servicios de Salud',
    'Enfermería en Salud Mental Psiquiatría': 'Enfermería en Salud Mental y Psiquiatría',
    'Fisiatría (Medicina Física y Familia': 'Fisiatría (Medicina Física y Rehabilitación)',
}

# Aplicar la corrección al DataFrame df_especialidad
df_especialidad['Especialidad'] = df_especialidad['Especialidad'].replace(corrections)

# Verificar los cambios
print("Especialidades corregidas:")
print(df_especialidad['Especialidad'].unique())
# Out:
# Especialidades corregidas:
# ['Alergia e Inmunología' 'Alergia e Inmunología Pediátrica'
#  'Anatomía Patológica' 'Anestesiología' 'Angiología General y Hemodinamia'
#  'Auditoría de Servicios de Salud' 'Cardiología' 'Cardiología Infantil'
#  'Cirugía Cardiovascular' 'Cirugía Cardiovascular Pediátric'
#  'Cirugía de Cabeza y Cuello' 'Cirugía de Tórax (Cirugía Torácica)'
#  'Cirugía General' 'Cirugía Infantil (Cirugía Pediátrica)'
#  'Cirugía Plástica y Reparadora' 'Cirugía Vascular Periférica'
#  'Clínica Médica' 'Coloproctología' 'Dermatología'
#  'Dermatología Pediátrica' 'Diagnóstico por Imágenes' 'Emergentología'
#  'Endocrinología' 'Endocrinología Infantil'
#  'Enfermería en Cuidados Paliativos' 'Enfermería en Salud del Adulto'
#  'Epidemiología' 'Especialidad de Endodoncia'
#  'Especialidad en Cirugía y Traumatología Bucomaxilofacial'
#  'Farmacología Clínica' 'Fisiatría (Medicina Física y Rehabilitación)'
#  'Gastroenterología' 'Gastroenterología Infantil' 'Genética Médica'
#  'Geriatría' 'Gestión de Servicios de Salud' 'Ginecología' 'Hematología'
#  'Hematología Infantil' 'Hemato-oncología Pediátrica'
#  'Hemoterapia e Inmunohema' 'Hepatología' 'Hepatología Pediátrica'
#  'Infectología' 'Infectología Infantil' 'Mastología'
#  'Medicina del Deporte' 'Medicina del Trabajo'
#  'Medicina General y/o Medicina de\nFamilia' 'Medicina Legal'
#  'Medicina Nuclear' 'Medicina Paliativa' 'Nefrología'
#  'Nefrología Infantil' 'Neonatología' 'Neumonología'
#  'Neumonología Infantil' 'Neurocirugía' 'Neurología' 'Neurología Infantil'
#  'Nutrición' 'Obstetricia' 'Oftalmología' 'Oncología' 'Oncología Infantil'
#  'Ortopedia y Traumatología' 'Ortopedia y Traumatología Infan'
#  'Otorrinolaringología' 'Pediatría' 'Psiquiatría'
#  'Psiquiatría Infanto Juvenil' 'Radioterapia o Terapia Radiante'
#  'Reumatología' 'Reumatología Infantil' 'Salud Pública'
#  'Terapia Intensiva' 'Terapia Intensiva Infantil' 'Tocoginecología'
#  'Toxicología' 'Urología' 'Cirugía infantil (Cirugía Pediátrica)'
#  'Electrofisiología cardíaca' 'Hemoterapia e Inmunohematología'
#  'Medicina General y/o Medicina de Familia'
#  'Ortopedia y Traumatología Infantil' 'Cirugía infantil (Cirugía Pediá'
#  'Cirugía Cardiovascular Pediátrica' 'Especialidad de Odontopediatría'
#  'Especialidad en Cirugía y\nTraumatología Bucomaxilofacial'
#  'Medicina General y/o Medicina Familia'
#  'Enfermería en Salud Mental y Psiquiatría'
#  'Medicina General y/o Medicina\nFamilia'
#  'Cirugía de Tórax (Cirugía Torácic' 'Salud Mental (R)']

# %%
df_especialidad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Especialidad           104 non-null    object
#  1   esp_bsas               80 non-null     float64
#  2   esp_cba                71 non-null     float64
#  3   esp_caba               80 non-null     float64
#  4   esp_mendoza            72 non-null     float64
#  5   esp_santafe            68 non-null     float64
#  6   esp_catamarca          43 non-null     float64
#  7   esp_formosa            46 non-null     float64
#  8   esp_entrerios          67 non-null     float64
#  9   esp_corrientes         59 non-null     float64
#  10  esp_jujuy              61 non-null     float64
#  11  esp_larioja            53 non-null     float64
#  12  esp_neuquen            66 non-null     float64
#  13  esp_rionegro           65 non-null     float64
#  14  esp_salta              64 non-null     float64
#  15  esp_sanluis            54 non-null     float64
#  16  esp_tierradelfuego     55 non-null     float64
#  17  esp_tucuman            64 non-null     float64
#  18  esp_chaco              58 non-null     float64
#  19  esp_lapampa            62 non-null     float64
#  20  esp_santacruz          48 non-null     float64
#  21  esp_chubut             63 non-null     float64
#  22  esp_sanjuan            67 non-null     float64
#  23  esp_misiones           58 non-null     float64
#  24  esp_santiagodelestero  53 non-null     float64
# dtypes: float64(24), object(1)
# memory usage: 20.4+ KB

# %%
df_1=df_especialidad.copy()

# %% [markdown]
# # **Preprocesamiento de datos**

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39692 entries, 8 to 825782
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   anio                           39692 non-null  int64
#  1   jurisdiccion_de_residencia_id  39692 non-null  int64
#  2   jurisdicion_residencia_nombre  39692 non-null  object
#  3   cie10_causa_id                 39692 non-null  object
#  4   cie10_clasificacion            39692 non-null  object
#  5   sexo_id                        39692 non-null  int64
#  6   Sexo                           39692 non-null  object
#  7   muerte_materna_id              39692 non-null  object
#  8   muerte_materna_clasificacion   39692 non-null  object
#  9   grupo_edad                     39692 non-null  object
#  10  cantidad                       39692 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 3.6+ MB

# %% [markdown]
#  La idea es asignar a cada motivo de defunción una especialidad, y ver si en esa provincia hay esa especialidad para poder analizar si, la muerte es debido a falta de establecimientos, o de inversión en especialistas.
#
#  Al verificar si en el lugar donde ocurrieron las defunciones había disponibilidad de la especialidad médica necesaria, se podría obtener información relevante sobre la accesibilidad a servicios de salud especializados y su posible impacto en las defunciones en diferentes áreas.
#
# Este análisis podría ayudar a identificar áreas con necesidades específicas de recursos de salud, áreas donde la disponibilidad de especialidades médicas es limitada, y áreas donde podrían ser necesarias mejoras en la planificación y gestión de recursos de salud para reducir las defunciones evitables.

# %%
# Agrupar por jurisdiccion_residencia_nombre (provincia) y cie10_clasificacion (causa de muerte)
df_causas_provincia = df2.groupby(['jurisdicion_residencia_nombre', 'cie10_clasificacion']).agg({'cantidad': 'sum'}).reset_index()

# Renombrar columnas para mayor claridad
df_causas_provincia.columns = ['Provincia', 'Causa_de_muerte', 'Cantidad_de_muertes']

# Ver el resultado
df_causas_provincia.head()
# Out:
#       Provincia                                    Causa_de_muerte  \
# 0  Buenos Aires                Absceso cutáneo, furúnculo y ántrax
# 1  Buenos Aires                Absceso del pulmón y del mediastino
# 2  Buenos Aires  Absceso y granuloma intracraneal e intrarraquídeo
# 3  Buenos Aires  Accidente de aeronave sin motor, con ocupante ...
# 4  Buenos Aires            Accidente de transporte no especificado
#
#    Cantidad_de_muertes
# 0                   16
# 1                   10
# 2                   13
# 3                    1
# 4                    1

# %%
# Agrupar por cie10_clasificacion (causa de muerte)
df_causas_totales = df2.groupby('cie10_clasificacion').agg({'cantidad': 'sum'}).reset_index()

# Renombrar columnas para mayor claridad
df_causas_totales.columns = ['Causa_de_muerte', 'Cantidad_de_muertes']

# Ver el resultado
df_causas_totales.head()
# Out:
#                          Causa_de_muerte  Cantidad_de_muertes
# 0                      Aborto espontáneo                    1
# 1                          Aborto médico                    1
# 2                 Aborto no especificado                    6
# 3    Absceso cutáneo, furúnculo y ántrax                   42
# 4  Absceso de las regiones anal y rectal                    7

# %%
# Ajustar las opciones de pandas para ver todos los elementos en un array
pd.set_option('display.max_seq_items', None)

# Listar todas las causas de muerte
causas_de_muerte = df2['cie10_clasificacion'].unique()

# Mostrar todas las causas de muerte
print(causas_de_muerte)
# Out:
# ['Sepsis bacteriana del recién nacido'
#  'Retardo del crecimiento fetal y desnutrición fetal'
#  'Otras malformaciones congénitas, no clasificadas en otra parte' ...
#  'Agresión con otros productos químicos y sustancias nocivas especificadas'
#  'Contacto con aire y gases calientes'
#  'Deficiencias de otros elementos nutricionales']

# %%
# Convertir a una lista y ordenar
causas_de_muerte_lista = df2['cie10_clasificacion'].unique()

# %%
print(len(causas_de_muerte_lista))
# Out:
# 1077

# %%
# Mostrar cada causa de muerte en una línea separada
for i in range(0,300,1):
    print(causas_de_muerte_lista[i])
# Out:
# Sepsis bacteriana del recién nacido
# Retardo del crecimiento fetal y desnutrición fetal
# Otras malformaciones congénitas, no clasificadas en otra parte
# Hipoxia intrauterina
# Malformaciones congénitas del sistema osteomuscular, no clasificadas en otra parte
# Agenesia renal y otras malformaciones hipoplásicas del riñón
# Síndrome de Edwards y síndrome  de Patau
# Púrpura y otras afecciones hemorrágicas
# Síndrome de la muerte súbita infantil
# Otras afecciones de la piel especificas del feto y del recién nacido
# Síndromes de aspiración neonatal
# Enfisema intersticial y afecciones relacionadas, originadas en el período perinatal
# Malformaciones congénitas de los tabiques cardíacos
# Feto y recién nacido afectado por complicaciones de la placenta, del cordón umbilical y de las membranas
# Malformaciones congénitas de las grandes venas
# Tumor maligno de los huesos y de los cartílagos articulares, de otros sitios y de sitios no especificados
# Otras causas mal definidas y las no especificadas de mortalidad
# Otras afecciones originadas en el período perinatal
# Neumonitis debida a sólidos y líquidos
# Anencefalia y malformaciones congénitas similares
# Otras anemias
# Otras anemias aplásticas
# Otros trastornos de los líquidos, de los electrólitos y del equilibrio ácido-básico
# Parálisis cerebral
# Asfixia del nacimiento
# Otros trastornos del encéfalo
# Sofocación y estrangulamiento accidental en la cama
# Síndrome de Down
# Malformaciones congénitas de las grandes arterias
# Neumonía bacteriana, no clasificada en otra parte
# Inhalación e ingestión de alimento que causa obstrucción de las vías respiratorias
# Hemorragia pulmonar originada en el período perinatal
# Otras anomalías cromosómicas, no clasificadas en otra parte
# Dificultad respiratoria del recién nacido
# Tuberculosis miliar
# Otras malformaciones congénitas del sistema circulatorio
# Infección viral de sitio no especificado
# Otros problemas respiratorios del recién nacido, originados en el período perinatal
# Complicaciones y descripciones mal definidas de enfermedad cardíaca
# Otros síndromes de malformaciones congénitas especificados que afectan múltiples sistemas
# Otros estrangulamientos y ahorcamientos accidentales
# Neumonía congénita
# Trastornos relacionados con duración corta de la gestación y con bajo peso al nacer, no clasificados en otra parte
# Estado de mal epiléptico
# Endocarditis aguda y subaguda
# Malformaciones congénitas del pulmón
# Edema pulmonar
# Ocupante de automóvil lesionado por colisión con  vehículo de transporte pesado o autobús
# Malformaciones congénitas de la columna vertebral y tórax óseo
# Trastornos transitorios del metabolismo de los carbohidratos específicos del feto y del recién nacido
# Bronquiolitis aguda
# Microcefalia
# Cardiomiopatía
# Enterocolitis necrotizante del feto y del recién nacido
# Trastornos cardiovasculares originados en el período perinatal
# Otras Sepsis
# Otras malformaciones congénitas del sistema respiratorio
# Otras malformaciones congénitas del sistema urinario
# Otras malformaciones congénitas del corazón
# Otros defectos de la coagulación
# Otros síntomas y signos que involucran los sistemas circulatorio y respiratorio
# Otros trastornos hematológicos perinatales
# Neumonía, organismo no especificado
# Feto y recién nacido afectado por condiciones de la madre no necesariamente relacionadas con el embarazo presente
# Otros hipotiroidismos
# Otras gastroenteritis y colitis de origen infeccioso y no especificado
# Coagulación intravascular diseminada en el feto y el recién nacido
# Neumotórax
# Meningitis bacteriana, no clasificada en otra parte
# Insuficiencia cardíaca
# Otras malformaciones congénitas del riñón
# Infección aguda no especificada de las vías respiratorias inferiores
# Insuficiencia respiratoria, no clasificada en otra parte
# Neumonía viral, no clasificada en otra parte
# Tumor de comportamiento incierto o desconocido del encéfalo y del sistema nervioso central
# Ausencia, atresia y estenosis congénita del intestino delgado
# Ausencia, atresia y estenosis congénita del intestino grueso
# Enfermedad debida a virus citomegálico
# Celulitis
# Coagulación intravascular diseminada [síndrome de desfibrinación]
# Otras arritmias cardiacas
# Ictiosis congénita
# Neumonía debida a otros microorganismos infecciosos, no clasificados en otra parte
# Sífilis congénita
# Hemorragia subaracnoidea
# Obstrucción no especificada de la respiración
# Epilepsia
# Influenza debida a virus no identificado
# Otros trastornos respiratorios
# Tumor maligno del corazón, del mediastino y de la pleura
# Otras enfermedades infecciosas y parasitarias congénitas
# Enfermedad quística del riñón
# Hidrocéfalo
# Feto y recién nacido afectados por complicaciones maternas del embarazo
# Otras alteraciones cerebrales del recién nacido
# Otras enfermedades pulmonares intersticiales
# Otras trisomías y trisomías parciales de los autosomas, no clasificadas en otra parte
# Otras miopatías
# Bronquitis aguda
# Otras inmunodeficiencias
# Desnutrición proteicocalórica severa, no especificada
# Hemorragia intracraneal no traumática del feto y del recién nacido
# Paro cardíaco
# Osteocondrodisplasia con defecto del crecimiento de los huesos largos y de la columna vertebral
# Inhalación e ingestión de otros objetos que causan obstrucción de las vías respiratorias
# Encefalocele
# Feto y recién nacido afectados por otras complicaciones del trabajo de parto y del parto
# Otras enfermedades infecciosas y las no especificadas
# Ocupante de automóvil lesionado por colisión con otro automóvil, camioneta o furgoneta
# Malformaciones congénitas del esófago
# Tumor maligno del encéfalo
# Leucemia linfoide
# Enfermedad respiratoria crónica originada en el período perinatal
# Hidrocéfalo congénito
# Influenza debida a ciertos virus de la influenza identificados
# Depleción del volumen
# Otras malformaciones congénitas del intestino
# Agranulocitosis
# Otros trastornos metabólicos
# Otras osteocondrodisplasias
# Malformaciones congénitas de la válvulas pulmonar y tricúspide
# Malformaciones congénitas de la vesícula biliar, de los conductos biliares y del hígado
# Agresión con fuerza corporal
# Otras enfermedades cardiopulmonares
# Otras malformaciones congénitas de los órganos genitales masculinos
# Otras malformaciones congénitas del encéfalo
# Otras enfermedades de las vías biliares
# Otros trastornos de la conducción
# Meningitis debida a otras causas y a las no especificadas
# Exposición a otras corrientes eléctricas especificadas
# Sexo indeterminado y seudohermafroditismo
# Inmunodeficiencia asociada con otros defectos mayores
# Monosomías y supresiones de los autosomas, no  clasificadas en otra parte
# Otras malformaciones congénitas de los huesos del cráneo y de la cara
# Exposición a fuego no controlado en edificio u otra construcción
# Malformaciones congénitas de las cámaras cardíacas y sus conexiones
# Trastornos del metabolismo de los aminoácidos de cadena ramificada y de los ácidos grasos
# Otros trastornos del metabolismo de los aminoácidos
# Inhalación de contenidos gástricos
# Mononucleosis infecciosa
# Otras infecciones especificas del período perinatal
# Candidiasis
# Síndrome nefrótico
# Leucemia mieloide
# Trastornos musculares primarios
# Síndrome nefrítico no especificado
# Otras malformaciones congénitas del sistema digestivo
# Otros trastornos del sistema urinario
# Enfermedades virales congénitas
# Exposición a humos, fuegos o llamas no especificados
# Otras enfermedades de los intestinos
# Enfermedad hemolítica del feto y del recién nacido
# Hidropesía fetal debida a enfermedad hemolítica
# Ictericia neonatal por otras causas y por las no especificadas
# Hipofunción y otros trastornos de la glándula hipófisis
# Uropatía obstructiva y por reflujo
# Síndrome de dificultad respiratoria del adulto
# Otras deformidades osteomusculares congénitas
# Enfermedad renal crónica
# Contacto traumático con arañas venenosas
# Ileo paralítico y obstrucción intestinal sin hernia
# Muerte sin asistencia
# Otros trastornos perinatales del sistema digestivo
# Tos ferina [tos convulsiva]
# Atrofia muscular espinal y síndromes afines
# Ocupante de automóvil lesionado en otros accidentes de transporte, y en los no especificados
# Trastornos del tono muscular del recién nacido
# Insuficiencia renal no especificada
# Otros maltratos
# Insuficiencia renal aguda
# Motociclista lesionado por colisión con vehículo de motor de dos o tres ruedas
# Neumonía debida a Streptococcus pneumoniae
# Otras intoxicaciones alimentarias bacterianas, no clasificadas en otra parte
# Otras hemorragias intracraneales no traumáticas
# Neumonía debida a Haemophilus influenzae
# Otras enfermedades del pericardio
# Malformaciones congénitas de la laringe
# Otras anomalías de los cromosomas sexuales, con fenotipo masculino, no clasificadas en otra parte
# Evento no especificado, de intención no determinada
# Exposición a corriente eléctrica no especificada
# Envenenamiento accidental por, y exposición a otros productos químicos y sustancias nocivas, y los no especificados
# Hernia diafragmática
# Otras malformaciones congénitas de la parte superior del tubo digestivo
# Peatón lesionado por colisión con automóvil, camioneta o furgoneta
# Hemorragia de las vías respiratorias
# Caída que implica cama
# Hernia no especificada de la cavidad abdominal
# Choque, no clasificado en otra parte
# Peritonitis
# Otras enfermedades de la médula espinal
# Otras infecciones locales de la piel y del tejido subcutáneo
# Ocupante de camioneta o furgoneta lesionado por colisión con vehículo de transporte pesado o autobús
# Hemangioma y linfangioma de cualquier sitio
# Otros trastornos de los leucocitos
# Tumor maligno de la glándula suprarrenal
# Ahogamiento y sumersión no especificados
# Exposición a factores no especificados
# Otras enfermedades de la sangre y de los órganos hematopoyéticos
# Otras malformaciones congénitas del sistema vascular periférico
# Agresión con objeto cortante
# Inmunodeficiencia con predominio de defectos de los anticuerpos
# Defectos obstructivos congénitos de la pelvis renal y malformaciones congénitas del uréter
# Trastornos vasculares de los intestinos
# Otros trastornos del metabolismo de los carbohidratos
# Otras afecciones de la pleura
# Tumor maligno de sitios no especificados
# Hemorragia intraencefálica
# Insuficiencia hepática, no clasificada en otra parte
# Otros síntomas y signos generales
# Hemorragia umbilical del recién nacido
# Caída no especificada
# Malformaciones congénitas de las válvulas aórtica y mitral
# Fibrosis quística
# Otros trastornos del sistema nervioso, no clasificados en otra parte
# Espina bífida
# Toxoplasmosis
# Somnolencia, estupor y coma
# Leucemia de células de tipo no especificado
# Poliarteritis nudosa y afecciones relacionadas
# Otras obstrucciones intestinales del recién nacido
# Contacto traumático con otras herramientas manuales y artefactos del hogar, con motor
# Otras enfermedades vasculares periféricas
# Otras enfermedades del estómago y del duodeno
# Kwashiorkor marasmático
# Hipotermia del recién nacido
# Cuerpo extraño que penetra por el ojo u orificio natural
# Enfermedad meningocócica
# Influenza debida a otro virus de la influenza identificado
# Infecciones herpética [herpes simple]
# Ahogamiento y sumersión mientras se está en una piscina
# Shigelosis
# Otras infecciones intestinales bacterianas
# Otros tumores de comportamiento incierto o desconocido del tejido linfático, de los órganos hematopoyéticos y de tejidos afines
# Miocarditis aguda
# Tumor maligno de la médula espinal, de los nervios craneales y de otras partes del sistema nervioso central
# Infecciones intestinales debidas a virus y otros organismos especificados
# Agresión por medios no especificados
# Malformaciones congénitas de la tráquea y de los bronquios
# Tumor de comportamiento incierto o desconocido de otros sitios y de los no especificados
# Enfermedad del reflujo gastroesofágico
# Otros ahogamientos y sumersiones especificados
# Efectos adversos de gases anestésicos y terapéuticos
# Dispositivos cardiovasculares asociados con incidentes adversos
# Cirugía y otros procedimientos quirúrgicos como la causa de reacción anormal del paciente o de complicación posterior, sin mención de incidente en el momento de efectuar el procedimiento
# Tuberculosis respiratoria, no confirmada bacteriológica o histológicamente
# Otras hemorragias neonatales
# Otras enfermedades especificadas con participación deL tejido linforreticular y del tejido reticulohistiocítico
# Inmunodeficiencias combinadas
# Ahorcamiento, estrangulamiento y sofocación, de intención no determinada
# Tumor maligno de otros tejidos conjuntivos y de tejidos blandos
# Feto y recién nacido afectados por influencias nocivas transmitidas a través de la placenta o de la leche materna
# Otras leucemias de tipo celular especificado
# Tuberculosis del sistema nervioso
# Ahogamiento y sumersión, de intención no determinada
# Contacto traumático con escorpión
# Encefalitis, mielitis y encefalomielitis
# Fisura del paladar con labio leporino
# Intervención legal
# Absceso y granuloma intracraneal e intrarraquídeo
# Enfermedad hemorrágica del feto y del recién nacido
# Otras malformaciones congénitas de la médula espinal
# Otras malformaciones congénitas del sistema nervioso
# Infecciones agudas de las vías respiratorias superiores, de sitios múltiples o no especificados
# Contacto con vapor de agua, vapores y objetos calientes, de intención no determinada
# Tumor benigno del encéfalo y de otras partes del sistema nervioso central
# Infección bacteriana de sitio no especificado
# Enfermedad por virus de la inmunodeficiencia humana [VIH], resultante en enfermedades infecciosas y parasitarias
# Tumor de comportamiento incierto o desconocido de la cavidad bucal y de los órganos digestivos
# Encefalitis viral, no especificada
# Exposición al humo, fuego y llamas, de intención no determinada
# Otras enfermedades pulmonares obstructivas crónicas
# Distonía
# Trastornos del metabolismo de los esfingolípidos y otros trastornos por almacenamiento de lípidos
# Contacto traumático con material explosivo, de intención no determinada
# Caída en o desde escalera o escalones
# Otras muertes súbitas de causa desconocida
# Desnutrición proteicocalórica, no especificada
# Enfermedad por virus de la inmunodeficiencia humana [VIH], sin otra especificación
# Envenenamiento accidental por, y exposición a otras drogas, medicamentos y sustancias biológicas, y los no especificados
# Accidente de transporte no especificado
# Envenenamiento accidental por, y exposición a otros gases y vapores
# Otros dispositivos médicos, y los no especificados, asociados con incidentes adversos
# Accidente de vehículo de motor o sin motor, tipo de vehículo no especificado
# Trastornos fibroblásticos
# Retraso mental grave
# Diabetes mellitus insulinodependiente
# Otros síndromes paralíticos
# Envenenamiento por, y  exposición a otros gases y vapores, de intención no determinada
# Ocupante de automóvil lesionado en accidente de transporte sin colisión
# Ocupante de camioneta o furgoneta lesionado en accidente de transporte sin colisión
# Secuelas de enfermedades inflamatorias del sistema nervioso central
# Golpe por objeto arrojado, proyectado o que cae
# Tumor maligno de otros sitios y de los sitios mal definidos
# Otras enfermedades desmielinizantes del sistema nervioso central
# Otras enfermedades degenerativas de los núcleos de la base
# Otros trastornos que afectan el mecanismo de la inmunidad, no clasificados en otra parte
# Leucemia monocítica
# Mordedura o ataque de perro
# Tumor maligno de los bronquios y del pulmón
# Otras enfermedades del sistema digestivo

# %% [markdown]
# Como hay demasiadas causas de muerte y el mapeo a la especialidad que se encarga de esa causa de muerte se debe realizar manualmente, lo vamos a realizar solo con las 15 causas de muertes mas recurrentes por provincia, y luego vamos a agregar una columna especialidad.
#
# Luego la idea es unirlo al dataframe de especialidades por provincia, para ver si coinciden, o si podría darnos un indicio de qué especialidades habría que agregar en cada provincia.

# %%
# Renombrar las columnas necesarias
df2.rename(columns={'jurisdicion_residencia_nombre': 'provincia_nombre', 'cie10_clasificacion': 'causa_defuncion'}, inplace=True)

# Agrupar por provincia y causa de muerte, contar la cantidad de registros y ordenar en orden descendente
causas_comunes = df2.groupby(['provincia_nombre', 'causa_defuncion']).size().reset_index(name='cantidad')
causas_comunes = causas_comunes.sort_values(['provincia_nombre', 'cantidad'], ascending=[True, False])

# Quedarse con las 5 causas de muerte más comunes por provincia
top_causas_comunes = causas_comunes.groupby('provincia_nombre').head(15)

# Visualizar la cantidad de datos resultantes
print(top_causas_comunes.groupby('provincia_nombre')['cantidad'].sum())
# Out:
# provincia_nombre
# Buenos Aires                                             759
# Catamarca                                                181
# Chaco                                                    270
# Chubut                                                   192
# Ciudad Autónoma de Buenos Aires                          380
# Corrientes                                               280
# Córdoba                                                  403
# Entre Ríos                                               272
# Formosa                                                  218
# Jujuy                                                    226
# La Pampa                                                 143
# La Rioja                                                 180
# Mendoza                                                  317
# Misiones                                                 251
# Neuquén                                                  209
# Río Negro                                                206
# Salta                                                    290
# San Juan                                                 227
# San Luis                                                 189
# Santa Cruz                                               156
# Santa Fe                                                 374
# Santiago del Estero                                      266
# Tierra del Fuego, Antártida e Islas del Atlántico Sur     95
# Tucumán                                                  320
# Name: cantidad, dtype: int64
# <ipython-input-41-3e902e7bd3b1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.rename(columns={'jurisdicion_residencia_nombre': 'provincia_nombre', 'cie10_clasificacion': 'causa_defuncion'}, inplace=True)

# %%
# Obtener una lista de las causas de muerte más comunes por provincia
causas_comunes_por_provincia = top_causas_comunes.groupby('provincia_nombre')['causa_defuncion'].apply(list).to_dict()

# Filtrar el DataFrame original para quedarse solo con las filas que contienen las causas de muerte más comunes por provincia
df_filtrado = df2[df2['provincia_nombre'].notnull() & df2.apply(lambda x: x['causa_defuncion'] in causas_comunes_por_provincia.get(x['provincia_nombre'], []), axis=1)]

# Mostrar el DataFrame filtrado
df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6404 entries, 376 to 825571
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   anio                           6404 non-null   int64
#  1   jurisdiccion_de_residencia_id  6404 non-null   int64
#  2   provincia_nombre               6404 non-null   object
#  3   cie10_causa_id                 6404 non-null   object
#  4   causa_defuncion                6404 non-null   object
#  5   sexo_id                        6404 non-null   int64
#  6   Sexo                           6404 non-null   object
#  7   muerte_materna_id              6404 non-null   object
#  8   muerte_materna_clasificacion   6404 non-null   object
#  9   grupo_edad                     6404 non-null   object
#  10  cantidad                       6404 non-null   int64
# dtypes: int64(4), object(7)
# memory usage: 600.4+ KB

# %%
top_causas_comunes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 360 entries, 125 to 9029
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   provincia_nombre  360 non-null    object
#  1   causa_defuncion   360 non-null    object
#  2   cantidad          360 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 11.2+ KB

# %%
df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6404 entries, 376 to 825571
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   anio                           6404 non-null   int64
#  1   jurisdiccion_de_residencia_id  6404 non-null   int64
#  2   provincia_nombre               6404 non-null   object
#  3   cie10_causa_id                 6404 non-null   object
#  4   causa_defuncion                6404 non-null   object
#  5   sexo_id                        6404 non-null   int64
#  6   Sexo                           6404 non-null   object
#  7   muerte_materna_id              6404 non-null   object
#  8   muerte_materna_clasificacion   6404 non-null   object
#  9   grupo_edad                     6404 non-null   object
#  10  cantidad                       6404 non-null   int64
# dtypes: int64(4), object(7)
# memory usage: 600.4+ KB

# %%
df_filtrado=df_filtrado.drop(['muerte_materna_id', 'muerte_materna_clasificacion'], axis=1)

# %%
# Contar el número de causas de defunción únicas en todo el DataFrame
num_causas_unicas = top_causas_comunes['causa_defuncion'].nunique()
print(f"El número de causas de defunción únicas en el top_causas_comunes es: {num_causas_unicas}")
# Out:
# El número de causas de defunción únicas en el top_causas_comunes es: 63

# %%
# Obtener las 47 causas de muerte únicas
causas_unicas = top_causas_comunes['causa_defuncion'].unique()

# Imprimir las 40 causas de muerte únicas
for index, causa in enumerate(causas_unicas, start=1):
    print(f"{index}. {causa}")
# Out:
# 1. Diabetes mellitus, no especificada
# 2. Evento no especificado, de intención no determinada
# 3. Insuficiencia cardíaca
# 4. Neumonía, organismo no especificado
# 5. Otros trastornos respiratorios
# 6. Insuficiencia respiratoria, no clasificada en otra parte
# 7. Lesión autoinfligida intencionalmente por ahorcamiento, estrangulamiento o sofocación
# 8. Otras enfermedades del sistema digestivo
# 9. Cardiomiopatía
# 10. Otras arritmias cardiacas
# 11. Disparo de otras armas de fuego, y las no especificadas, de intención no determinada
# 12. Ahorcamiento, estrangulamiento y sofocación, de intención no determinada
# 13. Aneurisma y disección aórticos
# 14. Leucemia mieloide
# 15. Enfermedad isquémica crónica del corazón
# 16. Otras Sepsis
# 17. Enfermedad renal crónica
# 18. Infarto agudo del miocardio
# 19. Embolia pulmonar
# 20. Otras causas mal definidas y las no especificadas de mortalidad
# 21. Choque, no clasificado en otra parte
# 22. Hipertensión esencial (primaria)
# 23. Peritonitis
# 24. Exposición a factores no especificados
# 25. Otras enfermedades pulmonares obstructivas crónicas
# 26. Diabetes mellitus no insulinodependiente
# 27. Tumor maligno de sitios no especificados
# 28. Cirugía y otros procedimientos quirúrgicos como la causa de reacción anormal del paciente o de complicación posterior, sin mención de incidente en el momento de efectuar el procedimiento
# 29. Complicaciones y descripciones mal definidas de enfermedad cardíaca
# 30. Ocupante de automóvil lesionado en otros accidentes de transporte, y en los no especificados
# 31. Infarto cerebral
# 32. Exposición a humos, fuegos o llamas no especificados
# 33. Hemorragia subaracnoidea
# 34. Tumor maligno del encéfalo
# 35. Otras enfermedades cerebrovasculares
# 36. Tumor maligno del páncreas
# 37. Hemorragia intraencefálica
# 38. Taquicardia paroxística
# 39. Insuficiencia hepática, no clasificada en otra parte
# 40. Muerte sin asistencia
# 41. Accidente de vehículo de motor o sin motor, tipo de vehículo no especificado
# 42. Tuberculosis respiratoria, no confirmada bacteriológica o histológicamente
# 43. Tumor de comportamiento incierto o desconocido del encéfalo y del sistema nervioso central
# 44. Insuficiencia renal aguda
# 45. Tumor maligno del hígado y de las vías biliares intrahepáticas
# 46. Accidente vascular encefálico agudo, no especificado como hemorrágico o isquémico
# 47. Fibrosis y cirrosis del hígado
# 48. Insuficiencia renal no especificada
# 49. Ocupante de automóvil lesionado por colisión con otro automóvil, camioneta o furgoneta
# 50. Dolor abdominal y pélvico
# 51. Tumor maligno del colon
# 52. Tumor maligno de los bronquios y del pulmón
# 53. Edema pulmonar
# 54. Motociclista lesionado por colisión con automóvil, camioneta o furgoneta
# 55. Peatón lesionado por colisión con automóvil, camioneta o furgoneta
# 56. Agresión con objeto cortante
# 57. Enfermedad alcohólica del hígado
# 58. Tumor maligno del estómago
# 59. Diabetes mellitus insulinodependiente
# 60. Enfermedad por virus de la inmunodeficiencia humana [VIH], resultante en enfermedades infecciosas y parasitarias
# 61. Agresión con disparo de otras armas de fuego, y las no especificadas
# 62. Tumor de comportamiento incierto o desconocido de la cavidad bucal y de los órganos digestivos
# 63. Otros trastornos del sistema urinario

# %% [markdown]
# Podemos ver que son 63 las causas, disminuimos mucho la cantidad de causas de muerte de mas de 1400 a 63, luego sino llegamos a una buena conclusion podriamos incluidar al top de causas de muertes más de 15.
#
# También podemos observar que disminuimos mucho los datos.

# %% [markdown]
# Vamos a asignar cada una de las 63 causas de defunción más comunes, una especialidades que podría ser requeridas.

# %%
df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6404 entries, 376 to 825571
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   anio                           6404 non-null   int64
#  1   jurisdiccion_de_residencia_id  6404 non-null   int64
#  2   provincia_nombre               6404 non-null   object
#  3   cie10_causa_id                 6404 non-null   object
#  4   causa_defuncion                6404 non-null   object
#  5   sexo_id                        6404 non-null   int64
#  6   Sexo                           6404 non-null   object
#  7   grupo_edad                     6404 non-null   object
#  8   cantidad                       6404 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 500.3+ KB

# %%
df_filtrado['grupo_edad'].unique()
# Out:
# array(['01.De a 0  a 14 anios', '02.De 15 a 34 anios',
#        '03.De 35 a 54 anios', '04.De 55 a 74 anios',
#        '05.De 75 anios y mas', '06.Sin especificar'], dtype=object)

# %%
# Función para determinar si el paciente pertenece a pediatría según el rango de edad
def es_pediatria(edad):
    if 'De a 0  a 14 anios' in edad:
        return True
    return False

# Agregar una columna al DataFrame que indique si el paciente pertenece a pediatría o no
df_filtrado['pediatria'] = df_filtrado['grupo_edad'].apply(es_pediatria)

# %%
df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6404 entries, 376 to 825571
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   anio                           6404 non-null   int64
#  1   jurisdiccion_de_residencia_id  6404 non-null   int64
#  2   provincia_nombre               6404 non-null   object
#  3   cie10_causa_id                 6404 non-null   object
#  4   causa_defuncion                6404 non-null   object
#  5   sexo_id                        6404 non-null   int64
#  6   Sexo                           6404 non-null   object
#  7   grupo_edad                     6404 non-null   object
#  8   cantidad                       6404 non-null   int64
#  9   pediatria                      6404 non-null   bool
# dtypes: bool(1), int64(4), object(5)
# memory usage: 506.6+ KB

# %%
df_especialidad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Especialidad           104 non-null    object
#  1   esp_bsas               80 non-null     float64
#  2   esp_cba                71 non-null     float64
#  3   esp_caba               80 non-null     float64
#  4   esp_mendoza            72 non-null     float64
#  5   esp_santafe            68 non-null     float64
#  6   esp_catamarca          43 non-null     float64
#  7   esp_formosa            46 non-null     float64
#  8   esp_entrerios          67 non-null     float64
#  9   esp_corrientes         59 non-null     float64
#  10  esp_jujuy              61 non-null     float64
#  11  esp_larioja            53 non-null     float64
#  12  esp_neuquen            66 non-null     float64
#  13  esp_rionegro           65 non-null     float64
#  14  esp_salta              64 non-null     float64
#  15  esp_sanluis            54 non-null     float64
#  16  esp_tierradelfuego     55 non-null     float64
#  17  esp_tucuman            64 non-null     float64
#  18  esp_chaco              58 non-null     float64
#  19  esp_lapampa            62 non-null     float64
#  20  esp_santacruz          48 non-null     float64
#  21  esp_chubut             63 non-null     float64
#  22  esp_sanjuan            67 non-null     float64
#  23  esp_misiones           58 non-null     float64
#  24  esp_santiagodelestero  53 non-null     float64
# dtypes: float64(24), object(1)
# memory usage: 20.4+ KB

# %%
# Diccionario de mapeo para correcciones
mapeo_correcciones = {
    'Cirugía Cardiovascular Pediátric': 'Cirugía Cardiovascular Pediátrica',
    'Cirugía infantil (Cirugía Pediá': 'Cirugía Infantil (Cirugía Pediátrica)',
    'Cirugía de Tórax (Cirugía Torácic': 'Cirugía de Tórax (Cirugía Torácica)',
    'Medicina General y/o Medicina\nFamilia': 'Medicina General y/o Medicina Familia',
    'Medicina General y/o Medicina': 'Medicina General y/o Medicina Familia',
    'Medicina General y/o Medicina de\nFamilia': 'Medicina General y/o Medicina Familia',
    'Fisiatría (Medicina Física y Familia': 'Fisiatría (Medicina Física y Rehabilitación)',
    'Enfermería en Salud Mental Psiquiatría': 'Enfermería en Salud Mental y Psiquiatría',
    'Especialidad en Cirugía y\nTraumatología Bucomaxilofacial': 'Especialidad en Cirugía y Traumatología Bucomaxilofacial',
    'Enfermería en Cuidados Paliativ': 'Enfermería en Cuidados Paliativos',
    'Auditoría de Servicios de Sal': 'Auditoría de Servicios de Salud',
    'Medicina General y/o Medicina Familia' : 'Medicina General y/o Medicina de Familia',
    'Cirugía Infantil (Cirugía Pediátrica)': 'Cirugía infantil (Cirugía Pediátrica)',
    'Ortopedia y Traumatología Infan': 'Ortopedia y Traumatología Infantil',
    'Hemoterapia e Inmunohema': 'Hemoterapia e Inmunohematología'

}

# Aplicar las correcciones al DataFrame
df_especialidades=df_especialidad.copy()
df_especialidades['Especialidad'] = df_especialidades['Especialidad'].replace(mapeo_correcciones)

df_especialidades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Especialidad           104 non-null    object
#  1   esp_bsas               80 non-null     float64
#  2   esp_cba                71 non-null     float64
#  3   esp_caba               80 non-null     float64
#  4   esp_mendoza            72 non-null     float64
#  5   esp_santafe            68 non-null     float64
#  6   esp_catamarca          43 non-null     float64
#  7   esp_formosa            46 non-null     float64
#  8   esp_entrerios          67 non-null     float64
#  9   esp_corrientes         59 non-null     float64
#  10  esp_jujuy              61 non-null     float64
#  11  esp_larioja            53 non-null     float64
#  12  esp_neuquen            66 non-null     float64
#  13  esp_rionegro           65 non-null     float64
#  14  esp_salta              64 non-null     float64
#  15  esp_sanluis            54 non-null     float64
#  16  esp_tierradelfuego     55 non-null     float64
#  17  esp_tucuman            64 non-null     float64
#  18  esp_chaco              58 non-null     float64
#  19  esp_lapampa            62 non-null     float64
#  20  esp_santacruz          48 non-null     float64
#  21  esp_chubut             63 non-null     float64
#  22  esp_sanjuan            67 non-null     float64
#  23  esp_misiones           58 non-null     float64
#  24  esp_santiagodelestero  53 non-null     float64
# dtypes: float64(24), object(1)
# memory usage: 20.4+ KB

# %% [markdown]
# Observemos que hay 104 especialidades

# %%
# Convertir todo el texto de la columna ESPECIALIDAD a mayúsculas
df_especialidades['Especialidad'] = df_especialidades['Especialidad'].str.upper()
mapeo_correcciones={'MEDICINA GENERAL Y/O MEDICINA DE FAMILIA':'MEDICINA GENERAL Y/O MEDICINA FAMILIA'}

df_especialidades['Especialidad'] = df_especialidades['Especialidad'].replace(mapeo_correcciones)

# %%
# Agrupar las filas por especialidad y sumar los valores de las columnas correspondientes a cada provincia
df_especialidades = df_especialidades.groupby('Especialidad', as_index=False).sum(numeric_only=True)

df_especialidades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Especialidad           84 non-null     object
#  1   esp_bsas               84 non-null     float64
#  2   esp_cba                84 non-null     float64
#  3   esp_caba               84 non-null     float64
#  4   esp_mendoza            84 non-null     float64
#  5   esp_santafe            84 non-null     float64
#  6   esp_catamarca          84 non-null     float64
#  7   esp_formosa            84 non-null     float64
#  8   esp_entrerios          84 non-null     float64
#  9   esp_corrientes         84 non-null     float64
#  10  esp_jujuy              84 non-null     float64
#  11  esp_larioja            84 non-null     float64
#  12  esp_neuquen            84 non-null     float64
#  13  esp_rionegro           84 non-null     float64
#  14  esp_salta              84 non-null     float64
#  15  esp_sanluis            84 non-null     float64
#  16  esp_tierradelfuego     84 non-null     float64
#  17  esp_tucuman            84 non-null     float64
#  18  esp_chaco              84 non-null     float64
#  19  esp_lapampa            84 non-null     float64
#  20  esp_santacruz          84 non-null     float64
#  21  esp_chubut             84 non-null     float64
#  22  esp_sanjuan            84 non-null     float64
#  23  esp_misiones           84 non-null     float64
#  24  esp_santiagodelestero  84 non-null     float64
# dtypes: float64(24), object(1)
# memory usage: 16.5+ KB

# %% [markdown]
# Ahora quedaron 84 especialidades

# %%
# Verificar si hay elementos nulos en alguna columna
nulos = df_especialidades.isnull().sum()

# Mostrar los resultados
print(nulos)
# Out:
# Especialidad             0
# esp_bsas                 0
# esp_cba                  0
# esp_caba                 0
# esp_mendoza              0
# esp_santafe              0
# esp_catamarca            0
# esp_formosa              0
# esp_entrerios            0
# esp_corrientes           0
# esp_jujuy                0
# esp_larioja              0
# esp_neuquen              0
# esp_rionegro             0
# esp_salta                0
# esp_sanluis              0
# esp_tierradelfuego       0
# esp_tucuman              0
# esp_chaco                0
# esp_lapampa              0
# esp_santacruz            0
# esp_chubut               0
# esp_sanjuan              0
# esp_misiones             0
# esp_santiagodelestero    0
# dtype: int64

# %%
df_especialidades['Especialidad'].unique()
# Out:
# array(['ALERGIA E INMUNOLOGÍA', 'ALERGIA E INMUNOLOGÍA PEDIÁTRICA',
#        'ANATOMÍA PATOLÓGICA', 'ANESTESIOLOGÍA',
#        'ANGIOLOGÍA GENERAL Y HEMODINAMIA',
#        'AUDITORÍA DE SERVICIOS DE SALUD', 'CARDIOLOGÍA',
#        'CARDIOLOGÍA INFANTIL', 'CIRUGÍA CARDIOVASCULAR',
#        'CIRUGÍA CARDIOVASCULAR PEDIÁTRICA', 'CIRUGÍA DE CABEZA Y CUELLO',
#        'CIRUGÍA DE TÓRAX (CIRUGÍA TORÁCICA)', 'CIRUGÍA GENERAL',
#        'CIRUGÍA INFANTIL (CIRUGÍA PEDIÁTRICA)',
#        'CIRUGÍA PLÁSTICA Y REPARADORA', 'CIRUGÍA VASCULAR PERIFÉRICA',
#        'CLÍNICA MÉDICA', 'COLOPROCTOLOGÍA', 'DERMATOLOGÍA',
#        'DERMATOLOGÍA PEDIÁTRICA', 'DIAGNÓSTICO POR IMÁGENES',
#        'ELECTROFISIOLOGÍA CARDÍACA', 'EMERGENTOLOGÍA', 'ENDOCRINOLOGÍA',
#        'ENDOCRINOLOGÍA INFANTIL', 'ENFERMERÍA EN CUIDADOS PALIATIVOS',
#        'ENFERMERÍA EN SALUD DEL ADULTO',
#        'ENFERMERÍA EN SALUD MENTAL Y PSIQUIATRÍA', 'EPIDEMIOLOGÍA',
#        'ESPECIALIDAD DE ENDODONCIA', 'ESPECIALIDAD DE ODONTOPEDIATRÍA',
#        'ESPECIALIDAD EN CIRUGÍA Y TRAUMATOLOGÍA BUCOMAXILOFACIAL',
#        'FARMACOLOGÍA CLÍNICA',
#        'FISIATRÍA (MEDICINA FÍSICA Y REHABILITACIÓN)',
#        'GASTROENTEROLOGÍA', 'GASTROENTEROLOGÍA INFANTIL',
#        'GENÉTICA MÉDICA', 'GERIATRÍA', 'GESTIÓN DE SERVICIOS DE SALUD',
#        'GINECOLOGÍA', 'HEMATO-ONCOLOGÍA PEDIÁTRICA', 'HEMATOLOGÍA',
#        'HEMATOLOGÍA INFANTIL', 'HEMOTERAPIA E INMUNOHEMATOLOGÍA',
#        'HEPATOLOGÍA', 'HEPATOLOGÍA PEDIÁTRICA', 'INFECTOLOGÍA',
#        'INFECTOLOGÍA INFANTIL', 'MASTOLOGÍA', 'MEDICINA DEL DEPORTE',
#        'MEDICINA DEL TRABAJO', 'MEDICINA GENERAL Y/O MEDICINA FAMILIA',
#        'MEDICINA LEGAL', 'MEDICINA NUCLEAR', 'MEDICINA PALIATIVA',
#        'NEFROLOGÍA', 'NEFROLOGÍA INFANTIL', 'NEONATOLOGÍA',
#        'NEUMONOLOGÍA', 'NEUMONOLOGÍA INFANTIL', 'NEUROCIRUGÍA',
#        'NEUROLOGÍA', 'NEUROLOGÍA INFANTIL', 'NUTRICIÓN', 'OBSTETRICIA',
#        'OFTALMOLOGÍA', 'ONCOLOGÍA', 'ONCOLOGÍA INFANTIL',
#        'ORTOPEDIA Y TRAUMATOLOGÍA', 'ORTOPEDIA Y TRAUMATOLOGÍA INFANTIL',
#        'OTORRINOLARINGOLOGÍA', 'PEDIATRÍA', 'PSIQUIATRÍA',
#        'PSIQUIATRÍA INFANTO JUVENIL', 'RADIOTERAPIA O TERAPIA RADIANTE',
#        'REUMATOLOGÍA', 'REUMATOLOGÍA INFANTIL', 'SALUD MENTAL (R)',
#        'SALUD PÚBLICA', 'TERAPIA INTENSIVA', 'TERAPIA INTENSIVA INFANTIL',
#        'TOCOGINECOLOGÍA', 'TOXICOLOGÍA', 'UROLOGÍA'], dtype=object)

# %%
# Lista de especialidades pediátricas
especialidades_pediatria = [ 'Alergia e Inmunología Pediátrica',
       'Cardiología Infantil','Cirugía Cardiovascular Pediátrica',
       'Cirugía Infantil (Cirugía Pediátrica)','Dermatología Pediátrica','Endocrinología Infantil',
       'Especialidad de Odontopediatría',
        'Gastroenterología Infantil',
      'Hemato-oncología Pediátrica',
       'Hematología Infantil',
       'Hepatología Pediátrica', 'Infectología Infantil',
        'Nefrología Infantil', 'Neonatología','Neumonología Infantil',
       'Neurología Infantil', 'Obstetricia', 'Oncología Infantil',
       'Ortopedia y Traumatología Infantil','Pediatría', 'Psiquiatría Infanto Juvenil',
       'Reumatología Infantil','Terapia Intensiva Infantil',
       ]
# Convertir todos los elementos de la lista a mayúsculas
especialidades_pediatria = [esp.upper() for esp in especialidades_pediatria]
# Función para determinar si la especialidad es de pediatría
def es_pediatria(especialidad):
    return especialidad in especialidades_pediatria

# Agregar una columna al DataFrame que indique si la especialidad es de pediatría
df_especialidades['especialidad_pediatria'] = df_especialidades['Especialidad'].apply(es_pediatria)

# Mostrar el DataFrame actualizado
df_especialidades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Especialidad            84 non-null     object
#  1   esp_bsas                84 non-null     float64
#  2   esp_cba                 84 non-null     float64
#  3   esp_caba                84 non-null     float64
#  4   esp_mendoza             84 non-null     float64
#  5   esp_santafe             84 non-null     float64
#  6   esp_catamarca           84 non-null     float64
#  7   esp_formosa             84 non-null     float64
#  8   esp_entrerios           84 non-null     float64
#  9   esp_corrientes          84 non-null     float64
#  10  esp_jujuy               84 non-null     float64
#  11  esp_larioja             84 non-null     float64
#  12  esp_neuquen             84 non-null     float64
#  13  esp_rionegro            84 non-null     float64
#  14  esp_salta               84 non-null     float64
#  15  esp_sanluis             84 non-null     float64
#  16  esp_tierradelfuego      84 non-null     float64
#  17  esp_tucuman             84 non-null     float64
#  18  esp_chaco               84 non-null     float64
#  19  esp_lapampa             84 non-null     float64
#  20  esp_santacruz           84 non-null     float64
#  21  esp_chubut              84 non-null     float64
#  22  esp_sanjuan             84 non-null     float64
#  23  esp_misiones            84 non-null     float64
#  24  esp_santiagodelestero   84 non-null     float64
#  25  especialidad_pediatria  84 non-null     bool
# dtypes: bool(1), float64(24), object(1)
# memory usage: 16.6+ KB

# %%
# Clasificación de los datos en pediatría o adultos según el rango de edad
df_pediatria_def = df_filtrado[df_filtrado['pediatria']==True]
df_adultos_def = df_filtrado[df_filtrado['pediatria']==False]

# %% [markdown]
# Ahora vamos a separarar las especialidades en pediatría y adultos.

# %%
# Clasificación de los datos en pediatría o adultos según el rango de edad
df_especialidades_ped = df_especialidades[df_especialidades['especialidad_pediatria']==True]
df_especialidades_adultos = df_especialidades[df_especialidades['especialidad_pediatria']==False]

# %% [markdown]
# # **Mapeo de causas de defunción a especialidades**

# %%
df_especialidades_ped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23 entries, 1 to 80
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Especialidad            23 non-null     object
#  1   esp_bsas                23 non-null     float64
#  2   esp_cba                 23 non-null     float64
#  3   esp_caba                23 non-null     float64
#  4   esp_mendoza             23 non-null     float64
#  5   esp_santafe             23 non-null     float64
#  6   esp_catamarca           23 non-null     float64
#  7   esp_formosa             23 non-null     float64
#  8   esp_entrerios           23 non-null     float64
#  9   esp_corrientes          23 non-null     float64
#  10  esp_jujuy               23 non-null     float64
#  11  esp_larioja             23 non-null     float64
#  12  esp_neuquen             23 non-null     float64
#  13  esp_rionegro            23 non-null     float64
#  14  esp_salta               23 non-null     float64
#  15  esp_sanluis             23 non-null     float64
#  16  esp_tierradelfuego      23 non-null     float64
#  17  esp_tucuman             23 non-null     float64
#  18  esp_chaco               23 non-null     float64
#  19  esp_lapampa             23 non-null     float64
#  20  esp_santacruz           23 non-null     float64
#  21  esp_chubut              23 non-null     float64
#  22  esp_sanjuan             23 non-null     float64
#  23  esp_misiones            23 non-null     float64
#  24  esp_santiagodelestero   23 non-null     float64
#  25  especialidad_pediatria  23 non-null     bool
# dtypes: bool(1), float64(24), object(1)
# memory usage: 4.7+ KB

# %%
df_especialidades_adultos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61 entries, 0 to 83
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Especialidad            61 non-null     object
#  1   esp_bsas                61 non-null     float64
#  2   esp_cba                 61 non-null     float64
#  3   esp_caba                61 non-null     float64
#  4   esp_mendoza             61 non-null     float64
#  5   esp_santafe             61 non-null     float64
#  6   esp_catamarca           61 non-null     float64
#  7   esp_formosa             61 non-null     float64
#  8   esp_entrerios           61 non-null     float64
#  9   esp_corrientes          61 non-null     float64
#  10  esp_jujuy               61 non-null     float64
#  11  esp_larioja             61 non-null     float64
#  12  esp_neuquen             61 non-null     float64
#  13  esp_rionegro            61 non-null     float64
#  14  esp_salta               61 non-null     float64
#  15  esp_sanluis             61 non-null     float64
#  16  esp_tierradelfuego      61 non-null     float64
#  17  esp_tucuman             61 non-null     float64
#  18  esp_chaco               61 non-null     float64
#  19  esp_lapampa             61 non-null     float64
#  20  esp_santacruz           61 non-null     float64
#  21  esp_chubut              61 non-null     float64
#  22  esp_sanjuan             61 non-null     float64
#  23  esp_misiones            61 non-null     float64
#  24  esp_santiagodelestero   61 non-null     float64
#  25  especialidad_pediatria  61 non-null     bool
# dtypes: bool(1), float64(24), object(1)
# memory usage: 12.5+ KB

# %%
df_adultos_def.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6049 entries, 80144 to 825571
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   anio                           6049 non-null   int64
#  1   jurisdiccion_de_residencia_id  6049 non-null   int64
#  2   provincia_nombre               6049 non-null   object
#  3   cie10_causa_id                 6049 non-null   object
#  4   causa_defuncion                6049 non-null   object
#  5   sexo_id                        6049 non-null   int64
#  6   Sexo                           6049 non-null   object
#  7   grupo_edad                     6049 non-null   object
#  8   cantidad                       6049 non-null   int64
#  9   pediatria                      6049 non-null   bool
# dtypes: bool(1), int64(4), object(5)
# memory usage: 478.5+ KB

# %%
df_pediatria_def.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 355 entries, 376 to 80025
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   anio                           355 non-null    int64
#  1   jurisdiccion_de_residencia_id  355 non-null    int64
#  2   provincia_nombre               355 non-null    object
#  3   cie10_causa_id                 355 non-null    object
#  4   causa_defuncion                355 non-null    object
#  5   sexo_id                        355 non-null    int64
#  6   Sexo                           355 non-null    object
#  7   grupo_edad                     355 non-null    object
#  8   cantidad                       355 non-null    int64
#  9   pediatria                      355 non-null    bool
# dtypes: bool(1), int64(4), object(5)
# memory usage: 28.1+ KB

# %%
df_especialidades_ped['Especialidad'].unique()
# Out:
# array(['ALERGIA E INMUNOLOGÍA PEDIÁTRICA', 'CARDIOLOGÍA INFANTIL',
#        'CIRUGÍA CARDIOVASCULAR PEDIÁTRICA',
#        'CIRUGÍA INFANTIL (CIRUGÍA PEDIÁTRICA)', 'DERMATOLOGÍA PEDIÁTRICA',
#        'ENDOCRINOLOGÍA INFANTIL', 'ESPECIALIDAD DE ODONTOPEDIATRÍA',
#        'GASTROENTEROLOGÍA INFANTIL', 'HEMATO-ONCOLOGÍA PEDIÁTRICA',
#        'HEMATOLOGÍA INFANTIL', 'HEPATOLOGÍA PEDIÁTRICA',
#        'INFECTOLOGÍA INFANTIL', 'NEFROLOGÍA INFANTIL', 'NEONATOLOGÍA',
#        'NEUMONOLOGÍA INFANTIL', 'NEUROLOGÍA INFANTIL', 'OBSTETRICIA',
#        'ONCOLOGÍA INFANTIL', 'ORTOPEDIA Y TRAUMATOLOGÍA INFANTIL',
#        'PEDIATRÍA', 'PSIQUIATRÍA INFANTO JUVENIL',
#        'REUMATOLOGÍA INFANTIL', 'TERAPIA INTENSIVA INFANTIL'],
#       dtype=object)

# %%
df_especialidades_adultos['Especialidad'].unique()
# Out:
# array(['ALERGIA E INMUNOLOGÍA', 'ANATOMÍA PATOLÓGICA', 'ANESTESIOLOGÍA',
#        'ANGIOLOGÍA GENERAL Y HEMODINAMIA',
#        'AUDITORÍA DE SERVICIOS DE SALUD', 'CARDIOLOGÍA',
#        'CIRUGÍA CARDIOVASCULAR', 'CIRUGÍA DE CABEZA Y CUELLO',
#        'CIRUGÍA DE TÓRAX (CIRUGÍA TORÁCICA)', 'CIRUGÍA GENERAL',
#        'CIRUGÍA PLÁSTICA Y REPARADORA', 'CIRUGÍA VASCULAR PERIFÉRICA',
#        'CLÍNICA MÉDICA', 'COLOPROCTOLOGÍA', 'DERMATOLOGÍA',
#        'DIAGNÓSTICO POR IMÁGENES', 'ELECTROFISIOLOGÍA CARDÍACA',
#        'EMERGENTOLOGÍA', 'ENDOCRINOLOGÍA',
#        'ENFERMERÍA EN CUIDADOS PALIATIVOS',
#        'ENFERMERÍA EN SALUD DEL ADULTO',
#        'ENFERMERÍA EN SALUD MENTAL Y PSIQUIATRÍA', 'EPIDEMIOLOGÍA',
#        'ESPECIALIDAD DE ENDODONCIA',
#        'ESPECIALIDAD EN CIRUGÍA Y TRAUMATOLOGÍA BUCOMAXILOFACIAL',
#        'FARMACOLOGÍA CLÍNICA',
#        'FISIATRÍA (MEDICINA FÍSICA Y REHABILITACIÓN)',
#        'GASTROENTEROLOGÍA', 'GENÉTICA MÉDICA', 'GERIATRÍA',
#        'GESTIÓN DE SERVICIOS DE SALUD', 'GINECOLOGÍA', 'HEMATOLOGÍA',
#        'HEMOTERAPIA E INMUNOHEMATOLOGÍA', 'HEPATOLOGÍA', 'INFECTOLOGÍA',
#        'MASTOLOGÍA', 'MEDICINA DEL DEPORTE', 'MEDICINA DEL TRABAJO',
#        'MEDICINA GENERAL Y/O MEDICINA FAMILIA', 'MEDICINA LEGAL',
#        'MEDICINA NUCLEAR', 'MEDICINA PALIATIVA', 'NEFROLOGÍA',
#        'NEUMONOLOGÍA', 'NEUROCIRUGÍA', 'NEUROLOGÍA', 'NUTRICIÓN',
#        'OFTALMOLOGÍA', 'ONCOLOGÍA', 'ORTOPEDIA Y TRAUMATOLOGÍA',
#        'OTORRINOLARINGOLOGÍA', 'PSIQUIATRÍA',
#        'RADIOTERAPIA O TERAPIA RADIANTE', 'REUMATOLOGÍA',
#        'SALUD MENTAL (R)', 'SALUD PÚBLICA', 'TERAPIA INTENSIVA',
#        'TOCOGINECOLOGÍA', 'TOXICOLOGÍA', 'UROLOGÍA'], dtype=object)

# %%
# Contar las causas de defunción en df_pediatria_def
causas_pediatria = df_pediatria_def['causa_defuncion'].value_counts()

# Mostrar las causas de defunción y su cantidad
print("Causas de defunción en df_pediatria_def:")
print(causas_pediatria)# Contar las causas de defunción en df_pediatria_def
# Out:
# Causas de defunción en df_pediatria_def:
# causa_defuncion
# Neumonía, organismo no especificado                                                                                                                                                           59
# Otras causas mal definidas y las no especificadas de mortalidad                                                                                                                               45
# Lesión autoinfligida intencionalmente por ahorcamiento, estrangulamiento o sofocación                                                                                                         31
# Otras Sepsis                                                                                                                                                                                  25
# Otros trastornos respiratorios                                                                                                                                                                20
# Insuficiencia cardíaca                                                                                                                                                                        17
# Insuficiencia respiratoria, no clasificada en otra parte                                                                                                                                      16
# Tumor maligno del encéfalo                                                                                                                                                                    16
# Evento no especificado, de intención no determinada                                                                                                                                           13
# Exposición a factores no especificados                                                                                                                                                        13
# Cardiomiopatía                                                                                                                                                                                 8
# Choque, no clasificado en otra parte                                                                                                                                                           7
# Ahorcamiento, estrangulamiento y sofocación, de intención no determinada                                                                                                                       6
# Leucemia mieloide                                                                                                                                                                              6
# Hemorragia intraencefálica                                                                                                                                                                     5
# Enfermedad renal crónica                                                                                                                                                                       4
# Insuficiencia hepática, no clasificada en otra parte                                                                                                                                           4
# Disparo de otras armas de fuego, y las no especificadas, de intención no determinada                                                                                                           4
# Diabetes mellitus, no especificada                                                                                                                                                             4
# Otras enfermedades pulmonares obstructivas crónicas                                                                                                                                            4
# Cirugía y otros procedimientos quirúrgicos como la causa de reacción anormal del paciente o de complicación posterior, sin mención de incidente en el momento de efectuar el procedimiento     4
# Otras arritmias cardiacas                                                                                                                                                                      4
# Muerte sin asistencia                                                                                                                                                                          4
# Ocupante de automóvil lesionado por colisión con otro automóvil, camioneta o furgoneta                                                                                                         4
# Accidente de vehículo de motor o sin motor, tipo de vehículo no especificado                                                                                                                   3
# Otras enfermedades del sistema digestivo                                                                                                                                                       3
# Tumor de comportamiento incierto o desconocido del encéfalo y del sistema nervioso central                                                                                                     3
# Agresión con disparo de otras armas de fuego, y las no especificadas                                                                                                                           3
# Complicaciones y descripciones mal definidas de enfermedad cardíaca                                                                                                                            2
# Peatón lesionado por colisión con automóvil, camioneta o furgoneta                                                                                                                             2
# Tuberculosis respiratoria, no confirmada bacteriológica o histológicamente                                                                                                                     2
# Motociclista lesionado por colisión con automóvil, camioneta o furgoneta                                                                                                                       2
# Edema pulmonar                                                                                                                                                                                 2
# Exposición a humos, fuegos o llamas no especificados                                                                                                                                           2
# Hemorragia subaracnoidea                                                                                                                                                                       1
# Insuficiencia renal aguda                                                                                                                                                                      1
# Otras enfermedades cerebrovasculares                                                                                                                                                           1
# Agresión con objeto cortante                                                                                                                                                                   1
# Peritonitis                                                                                                                                                                                    1
# Enfermedad por virus de la inmunodeficiencia humana [VIH], resultante en enfermedades infecciosas y parasitarias                                                                               1
# Tumor de comportamiento incierto o desconocido de la cavidad bucal y de los órganos digestivos                                                                                                 1
# Aneurisma y disección aórticos                                                                                                                                                                 1
# Name: count, dtype: int64

# %%
enum_especialidades_pediatria=df_especialidades_ped['Especialidad'].value_counts()

print(enum_especialidades_pediatria)
# Out:
# Especialidad
# ALERGIA E INMUNOLOGÍA PEDIÁTRICA         1
# NEFROLOGÍA INFANTIL                      1
# REUMATOLOGÍA INFANTIL                    1
# PSIQUIATRÍA INFANTO JUVENIL              1
# PEDIATRÍA                                1
# ORTOPEDIA Y TRAUMATOLOGÍA INFANTIL       1
# ONCOLOGÍA INFANTIL                       1
# OBSTETRICIA                              1
# NEUROLOGÍA INFANTIL                      1
# NEUMONOLOGÍA INFANTIL                    1
# NEONATOLOGÍA                             1
# INFECTOLOGÍA INFANTIL                    1
# CARDIOLOGÍA INFANTIL                     1
# HEPATOLOGÍA PEDIÁTRICA                   1
# HEMATOLOGÍA INFANTIL                     1
# HEMATO-ONCOLOGÍA PEDIÁTRICA              1
# GASTROENTEROLOGÍA INFANTIL               1
# ESPECIALIDAD DE ODONTOPEDIATRÍA          1
# ENDOCRINOLOGÍA INFANTIL                  1
# DERMATOLOGÍA PEDIÁTRICA                  1
# CIRUGÍA INFANTIL (CIRUGÍA PEDIÁTRICA)    1
# CIRUGÍA CARDIOVASCULAR PEDIÁTRICA        1
# TERAPIA INTENSIVA INFANTIL               1
# Name: count, dtype: int64

# %%
df_pediatria_def.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 355 entries, 376 to 80025
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   anio                           355 non-null    int64
#  1   jurisdiccion_de_residencia_id  355 non-null    int64
#  2   provincia_nombre               355 non-null    object
#  3   cie10_causa_id                 355 non-null    object
#  4   causa_defuncion                355 non-null    object
#  5   sexo_id                        355 non-null    int64
#  6   Sexo                           355 non-null    object
#  7   grupo_edad                     355 non-null    object
#  8   cantidad                       355 non-null    int64
#  9   pediatria                      355 non-null    bool
# dtypes: bool(1), int64(4), object(5)
# memory usage: 28.1+ KB

# %%
# Diccionario de mapeo de causas de muerte a especialidades
map_causa_especialidad = {
    'Neumonía, organismo no especificado': 'NEUMONOLOGÍA INFANTIL',
    'Otras causas mal definidas y las no especificadas de mortalidad': 'PEDIATRÍA',
    'Lesión autoinfligida intencionalmente por ahorcamiento, estrangulamiento o sofocación': 'PSIQUIATRÍA INFANTO JUVENIL',
    'Otras Sepsis': 'INFECTOLOGÍA INFANTIL',
    'Otros trastornos respiratorios': 'NEUMONOLOGÍA INFANTIL',
    'Insuficiencia cardíaca': 'CARDIOLOGÍA INFANTIL',
    'Insuficiencia respiratoria, no clasificada en otra parte': 'NEUMONOLOGÍA INFANTIL',
    'Tumor maligno del encéfalo': 'ONCOLOGÍA INFANTIL',
    'Evento no especificado, de intención no determinada': 'PEDIATRÍA',
    'Exposición a factores no especificados': 'PEDIATRÍA',
    'Cardiomiopatía': 'CARDIOLOGÍA INFANTIL',
    'Choque, no clasificado en otra parte': 'PEDIATRÍA',
    'Ahorcamiento, estrangulamiento y sofocación, de intención no determinada': 'PSIQUIATRÍA INFANTO JUVENIL',
    'Leucemia mieloide': 'HEMATOLOGÍA INFANTIL',
    'Hemorragia intraencefálica': 'NEUROLOGÍA INFANTIL',
    'Enfermedad renal crónica': 'NEFROLOGÍA INFANTIL',
    'Insuficiencia hepática, no clasificada en otra parte': 'HEPATOLOGÍA PEDIÁTRICA',
    'Disparo de otras armas de fuego, y las no especificadas, de intención no determinada': 'PEDIATRÍA',
    'Diabetes mellitus, no especificada': 'ENDOCRINOLOGÍA INFANTIL',
    'Otras enfermedades pulmonares obstructivas crónicas': 'NEUMONOLOGÍA INFANTIL',
    'Cirugía y otros procedimientos quirúrgicos como la causa de reacción anormal del paciente o de complicación posterior, sin mención de incidente en el momento de efectuar el procedimiento': 'CIRUGÍA INFANTIL (CIRUGÍA PEDIÁTRICA)',
    'Otras arritmias cardiacas': 'CARDIOLOGÍA INFANTIL',
    'Muerte sin asistencia': 'PEDIATRÍA',
    'Ocupante de automóvil lesionado por colisión con otro automóvil, camioneta o furgoneta': 'TRAUMATOLOGÍA INFANTIL',
    'Accidente de vehículo de motor o sin motor, tipo de vehículo no especificado': 'TRAUMATOLOGÍA INFANTIL',
    'Otras enfermedades del sistema digestivo': 'GASTROENTEROLOGÍA INFANTIL',
    'Tumor de comportamiento incierto o desconocido del encéfalo y del sistema nervioso central': 'ONCOLOGÍA INFANTIL',
    'Agresión con disparo de otras armas de fuego, y las no especificadas': 'PEDIATRÍA',
    'Complicaciones y descripciones mal definidas de enfermedad cardíaca': 'CARDIOLOGÍA INFANTIL',
    'Peatón lesionado por colisión con automóvil, camioneta o furgoneta': 'TRAUMATOLOGÍA INFANTIL',
    'Tuberculosis respiratoria, no confirmada bacteriológica o histológicamente': 'NEUMONOLOGÍA INFANTIL',
    'Motociclista lesionado por colisión con automóvil, camioneta o furgoneta': 'TRAUMATOLOGÍA INFANTIL',
    'Edema pulmonar': 'CARDIOLOGÍA INFANTIL',
    'Exposición a humos, fuegos o llamas no especificados': 'PEDIATRÍA',
    'Hemorragia subaracnoidea': 'NEUROLOGÍA INFANTIL',
    'Insuficiencia renal aguda': 'NEFROLOGÍA INFANTIL',
    'Otras enfermedades cerebrovasculares': 'NEUROLOGÍA INFANTIL',
    'Agresión con objeto cortante': 'PEDIATRÍA',
    'Peritonitis': 'GASTROENTEROLOGÍA INFANTIL',
    'Enfermedad por virus de la inmunodeficiencia humana [VIH], resultante en enfermedades infecciosas y parasitarias': 'INFECTOLOGÍA INFANTIL',
    'Tumor de comportamiento incierto o desconocido de la cavidad bucal y de los órganos digestivos': 'ONCOLOGÍA INFANTIL',
    'Aneurisma y disección aórticos': 'CARDIOLOGÍA INFANTIL'
}

# Crear una nueva columna 'Especialidad' en el DataFrame df_pediatria_def basada en el mapeo
df_pediatria_def['Especialidad'] = df_pediatria_def['causa_defuncion'].map(map_causa_especialidad)

# Mostrar el DataFrame actualizado
df_pediatria_def.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 355 entries, 376 to 80025
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   anio                           355 non-null    int64
#  1   jurisdiccion_de_residencia_id  355 non-null    int64
#  2   provincia_nombre               355 non-null    object
#  3   cie10_causa_id                 355 non-null    object
#  4   causa_defuncion                355 non-null    object
#  5   sexo_id                        355 non-null    int64
#  6   Sexo                           355 non-null    object
#  7   grupo_edad                     355 non-null    object
#  8   cantidad                       355 non-null    int64
#  9   Especialidad                   355 non-null    object
#  10  especialidad_disponible        355 non-null    int64
# dtypes: int64(5), object(6)
# memory usage: 33.3+ KB
# <ipython-input-118-9f32a5546e5b>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pediatria_def['Especialidad'] = df_pediatria_def['causa_defuncion'].map(map_causa_especialidad)

# %% [markdown]
# Podemos ver que df_pediatria_def ya tiene la columna especialidad

# %%
# Verificar si todas las especialidades en df_pediatria_def['Especialidad'] están en la lista especialidades_pediatria
especialidades_validas = df_pediatria_def['Especialidad'].isin(especialidades_pediatria)

# Filtrar las especialidades no válidas
especialidades_invalidas = df_pediatria_def[~especialidades_validas]

# Imprimir el resultado
if especialidades_invalidas.empty:
    print("Todas las especialidades son válidas.")
else:
    print("Existen especialidades no válidas:")
    print(especialidades_invalidas[['causa_defuncion', 'Especialidad']])
# Out:
# Existen especialidades no válidas:
#                                          causa_defuncion  \
# 5635   Ocupante de automóvil lesionado por colisión c...
# 46267  Peatón lesionado por colisión con automóvil, c...
# 52932  Motociclista lesionado por colisión con automó...
# 52991  Ocupante de automóvil lesionado por colisión c...
# 53955  Peatón lesionado por colisión con automóvil, c...
# 58464  Accidente de vehículo de motor o sin motor, ti...
# 60856  Accidente de vehículo de motor o sin motor, ti...
# 66225  Accidente de vehículo de motor o sin motor, ti...
# 70222  Motociclista lesionado por colisión con automó...
# 73354  Ocupante de automóvil lesionado por colisión c...
# 76948  Ocupante de automóvil lesionado por colisión c...
#
#                  Especialidad
# 5635   TRAUMATOLOGÍA INFANTIL
# 46267  TRAUMATOLOGÍA INFANTIL
# 52932  TRAUMATOLOGÍA INFANTIL
# 52991  TRAUMATOLOGÍA INFANTIL
# 53955  TRAUMATOLOGÍA INFANTIL
# 58464  TRAUMATOLOGÍA INFANTIL
# 60856  TRAUMATOLOGÍA INFANTIL
# 66225  TRAUMATOLOGÍA INFANTIL
# 70222  TRAUMATOLOGÍA INFANTIL
# 73354  TRAUMATOLOGÍA INFANTIL
# 76948  TRAUMATOLOGÍA INFANTIL

# %% [markdown]
# Ahora vamos a hacer lo mismo pero con los data frame que tienen los datos de los Adultos:

# %%
# Asegúrate de ajustar las opciones de visualización de pandas
pd.set_option('display.max_rows', None)

# Contar las causas de defunción en df_adultos_def
causas_adultos = df_adultos_def['causa_defuncion'].value_counts()

# Imprimir el número total de causas de defunción
print(len(causas_adultos))

# Mostrar las causas de defunción y su cantidad
print("Causas de defunción en df_adultos_def:")
print(causas_adultos)
# Out:
# 63
# Causas de defunción en df_adultos_def:
# causa_defuncion
# Diabetes mellitus, no especificada                                                                                                                                                            604
# Neumonía, organismo no especificado                                                                                                                                                           453
# Insuficiencia cardíaca                                                                                                                                                                        383
# Lesión autoinfligida intencionalmente por ahorcamiento, estrangulamiento o sofocación                                                                                                         362
# Otros trastornos respiratorios                                                                                                                                                                220
# Otras causas mal definidas y las no especificadas de mortalidad                                                                                                                               218
# Enfermedad renal crónica                                                                                                                                                                      199
# Enfermedad isquémica crónica del corazón                                                                                                                                                      199
# Otras enfermedades pulmonares obstructivas crónicas                                                                                                                                           196
# Otras Sepsis                                                                                                                                                                                  190
# Diabetes mellitus no insulinodependiente                                                                                                                                                      190
# Insuficiencia respiratoria, no clasificada en otra parte                                                                                                                                      185
# Otras arritmias cardiacas                                                                                                                                                                     174
# Cardiomiopatía                                                                                                                                                                                173
# Otras enfermedades del sistema digestivo                                                                                                                                                      166
# Hemorragia intraencefálica                                                                                                                                                                    154
# Infarto agudo del miocardio                                                                                                                                                                   137
# Choque, no clasificado en otra parte                                                                                                                                                          126
# Tumor maligno del encéfalo                                                                                                                                                                    121
# Evento no especificado, de intención no determinada                                                                                                                                           119
# Aneurisma y disección aórticos                                                                                                                                                                112
# Exposición a factores no especificados                                                                                                                                                        100
# Tumor maligno de sitios no especificados                                                                                                                                                       99
# Ahorcamiento, estrangulamiento y sofocación, de intención no determinada                                                                                                                       79
# Insuficiencia hepática, no clasificada en otra parte                                                                                                                                           75
# Cirugía y otros procedimientos quirúrgicos como la causa de reacción anormal del paciente o de complicación posterior, sin mención de incidente en el momento de efectuar el procedimiento     74
# Leucemia mieloide                                                                                                                                                                              60
# Tumor maligno del colon                                                                                                                                                                        59
# Tumor maligno del hígado y de las vías biliares intrahepáticas                                                                                                                                 58
# Taquicardia paroxística                                                                                                                                                                        54
# Otras enfermedades cerebrovasculares                                                                                                                                                           54
# Complicaciones y descripciones mal definidas de enfermedad cardíaca                                                                                                                            52
# Disparo de otras armas de fuego, y las no especificadas, de intención no determinada                                                                                                           42
# Tumor maligno del páncreas                                                                                                                                                                     40
# Hemorragia subaracnoidea                                                                                                                                                                       32
# Muerte sin asistencia                                                                                                                                                                          28
# Tumor maligno del estómago                                                                                                                                                                     28
# Peritonitis                                                                                                                                                                                    28
# Fibrosis y cirrosis del hígado                                                                                                                                                                 27
# Tumor maligno de los bronquios y del pulmón                                                                                                                                                    26
# Tuberculosis respiratoria, no confirmada bacteriológica o histológicamente                                                                                                                     26
# Tumor de comportamiento incierto o desconocido del encéfalo y del sistema nervioso central                                                                                                     26
# Insuficiencia renal aguda                                                                                                                                                                      22
# Agresión con disparo de otras armas de fuego, y las no especificadas                                                                                                                           21
# Tumor de comportamiento incierto o desconocido de la cavidad bucal y de los órganos digestivos                                                                                                 21
# Accidente de vehículo de motor o sin motor, tipo de vehículo no especificado                                                                                                                   21
# Embolia pulmonar                                                                                                                                                                               20
# Insuficiencia renal no especificada                                                                                                                                                            19
# Accidente vascular encefálico agudo, no especificado como hemorrágico o isquémico                                                                                                              18
# Enfermedad por virus de la inmunodeficiencia humana [VIH], resultante en enfermedades infecciosas y parasitarias                                                                               18
# Ocupante de automóvil lesionado por colisión con otro automóvil, camioneta o furgoneta                                                                                                         17
# Enfermedad alcohólica del hígado                                                                                                                                                               17
# Ocupante de automóvil lesionado en otros accidentes de transporte, y en los no especificados                                                                                                   13
# Infarto cerebral                                                                                                                                                                               12
# Diabetes mellitus insulinodependiente                                                                                                                                                          12
# Agresión con objeto cortante                                                                                                                                                                   11
# Motociclista lesionado por colisión con automóvil, camioneta o furgoneta                                                                                                                       11
# Peatón lesionado por colisión con automóvil, camioneta o furgoneta                                                                                                                             11
# Hipertensión esencial (primaria)                                                                                                                                                                9
# Exposición a humos, fuegos o llamas no especificados                                                                                                                                            8
# Dolor abdominal y pélvico                                                                                                                                                                       8
# Edema pulmonar                                                                                                                                                                                  7
# Otros trastornos del sistema urinario                                                                                                                                                           5
# Name: count, dtype: int64

# %%
enum_especialidades_adultos=df_especialidades_adultos['Especialidad'].value_counts()
print(enum_especialidades_adultos.to_string())
# Out:
# Especialidad
# ALERGIA E INMUNOLOGÍA                                       1
# GINECOLOGÍA                                                 1
# HEMOTERAPIA E INMUNOHEMATOLOGÍA                             1
# HEPATOLOGÍA                                                 1
# INFECTOLOGÍA                                                1
# MASTOLOGÍA                                                  1
# MEDICINA DEL DEPORTE                                        1
# MEDICINA DEL TRABAJO                                        1
# MEDICINA GENERAL Y/O MEDICINA FAMILIA                       1
# MEDICINA LEGAL                                              1
# MEDICINA NUCLEAR                                            1
# MEDICINA PALIATIVA                                          1
# NEFROLOGÍA                                                  1
# NEUMONOLOGÍA                                                1
# NEUROCIRUGÍA                                                1
# NEUROLOGÍA                                                  1
# NUTRICIÓN                                                   1
# OFTALMOLOGÍA                                                1
# ONCOLOGÍA                                                   1
# ORTOPEDIA Y TRAUMATOLOGÍA                                   1
# OTORRINOLARINGOLOGÍA                                        1
# PSIQUIATRÍA                                                 1
# RADIOTERAPIA O TERAPIA RADIANTE                             1
# REUMATOLOGÍA                                                1
# SALUD MENTAL (R)                                            1
# SALUD PÚBLICA                                               1
# TERAPIA INTENSIVA                                           1
# TOCOGINECOLOGÍA                                             1
# TOXICOLOGÍA                                                 1
# HEMATOLOGÍA                                                 1
# GESTIÓN DE SERVICIOS DE SALUD                               1
# ANATOMÍA PATOLÓGICA                                         1
# GERIATRÍA                                                   1
# ANESTESIOLOGÍA                                              1
# ANGIOLOGÍA GENERAL Y HEMODINAMIA                            1
# AUDITORÍA DE SERVICIOS DE SALUD                             1
# CARDIOLOGÍA                                                 1
# CIRUGÍA CARDIOVASCULAR                                      1
# CIRUGÍA DE CABEZA Y CUELLO                                  1
# CIRUGÍA DE TÓRAX (CIRUGÍA TORÁCICA)                         1
# CIRUGÍA GENERAL                                             1
# CIRUGÍA PLÁSTICA Y REPARADORA                               1
# CIRUGÍA VASCULAR PERIFÉRICA                                 1
# CLÍNICA MÉDICA                                              1
# COLOPROCTOLOGÍA                                             1
# DERMATOLOGÍA                                                1
# DIAGNÓSTICO POR IMÁGENES                                    1
# ELECTROFISIOLOGÍA CARDÍACA                                  1
# EMERGENTOLOGÍA                                              1
# ENDOCRINOLOGÍA                                              1
# ENFERMERÍA EN CUIDADOS PALIATIVOS                           1
# ENFERMERÍA EN SALUD DEL ADULTO                              1
# ENFERMERÍA EN SALUD MENTAL Y PSIQUIATRÍA                    1
# EPIDEMIOLOGÍA                                               1
# ESPECIALIDAD DE ENDODONCIA                                  1
# ESPECIALIDAD EN CIRUGÍA Y TRAUMATOLOGÍA BUCOMAXILOFACIAL    1
# FARMACOLOGÍA CLÍNICA                                        1
# FISIATRÍA (MEDICINA FÍSICA Y REHABILITACIÓN)                1
# GASTROENTEROLOGÍA                                           1
# GENÉTICA MÉDICA                                             1
# UROLOGÍA                                                    1

# %%
# Definir el mapeo de causas de defunción a especialidades
mapeo_especialidades = {
    'Diabetes mellitus, no especificada': 'ENDOCRINOLOGÍA',
    'Neumonía, organismo no especificado': 'NEUMONOLOGÍA',
    'Insuficiencia cardíaca': 'CARDIOLOGÍA',
    'Lesión autoinfligida intencionalmente por ahorcamiento, estrangulamiento o sofocación': 'PSIQUIATRÍA',
    'Otros trastornos respiratorios': 'NEUMONOLOGÍA',
    'Otras causas mal definidas y las no especificadas de mortalidad': 'MEDICINA GENERAL Y/O MEDICINA FAMILIA',
    'Enfermedad renal crónica': 'NEFROLOGÍA',
    'Enfermedad isquémica crónica del corazón': 'CARDIOLOGÍA',
    'Otras enfermedades pulmonares obstructivas crónicas': 'NEUMONOLOGÍA',
    'Otras Sepsis': 'INFECTOLOGÍA',
    'Diabetes mellitus no insulinodependiente': 'ENDOCRINOLOGÍA',
    'Insuficiencia respiratoria, no clasificada en otra parte': 'NEUMONOLOGÍA',
    'Otras arritmias cardiacas': 'CARDIOLOGÍA',
    'Cardiomiopatía': 'CARDIOLOGÍA',
    'Otras enfermedades del sistema digestivo': 'GASTROENTEROLOGÍA',
    'Hemorragia intraencefálica': 'NEUROLOGÍA',
    'Infarto agudo del miocardio': 'CARDIOLOGÍA',
    'Choque, no clasificado en otra parte': 'MEDICINA DE EMERGENCIA',
    'Tumor maligno del encéfalo': 'ONCOLOGÍA',
    'Evento no especificado, de intención no determinada': 'MEDICINA LEGAL',
    'Aneurisma y disección aórticos': 'CIRUGÍA CARDIOVASCULAR',
    'Exposición a factores no especificados': 'MEDICINA LEGAL',
    'Tumor maligno de sitios no especificados': 'ONCOLOGÍA',
    'Ahorcamiento, estrangulamiento y sofocación, de intención no determinada': 'MEDICINA LEGAL',
    'Insuficiencia hepática, no clasificada en otra parte': 'HEPATOLOGÍA',
    'Cirugía y otros procedimientos quirúrgicos como la causa de reacción anormal del paciente o de complicación posterior, sin mención de incidente en el momento de efectuar el procedimiento': 'CIRUGÍA GENERAL',
    'Leucemia mieloide': 'HEMATOLOGÍA',
    'Tumor maligno del colon': 'ONCOLOGÍA',
    'Tumor maligno del hígado y de las vías biliares intrahepáticas': 'ONCOLOGÍA',
    'Taquicardia paroxística': 'CARDIOLOGÍA',
    'Otras enfermedades cerebrovasculares': 'NEUROLOGÍA',
    'Complicaciones y descripciones mal definidas de enfermedad cardíaca': 'CARDIOLOGÍA',
    'Disparo de otras armas de fuego, y las no especificadas, de intención no determinada': 'MEDICINA LEGAL',
    'Tumor maligno del páncreas': 'ONCOLOGÍA',
    'Hemorragia subaracnoidea': 'NEUROCIRUGÍA',
    'Muerte sin asistencia': 'MEDICINA LEGAL',
    'Tumor maligno del estómago': 'ONCOLOGÍA',
    'Peritonitis': 'GASTROENTEROLOGÍA',
    'Fibrosis y cirrosis del hígado': 'HEPATOLOGÍA',
    'Tumor maligno de los bronquios y del pulmón': 'ONCOLOGÍA',
    'Tuberculosis respiratoria, no confirmada bacteriológica o histológicamente': 'INFECTOLOGÍA',
    'Tumor de comportamiento incierto o desconocido del encéfalo y del sistema nervioso central': 'ONCOLOGÍA',
    'Insuficiencia renal aguda': 'NEFROLOGÍA',
    'Agresión con disparo de otras armas de fuego, y las no especificadas': 'MEDICINA LEGAL',
    'Tumor de comportamiento incierto o desconocido de la cavidad bucal y de los órganos digestivos': 'ONCOLOGÍA',
    'Accidente de vehículo de motor o sin motor, tipo de vehículo no especificado': 'TRAUMATOLOGÍA',
    'Embolia pulmonar': 'NEUMONOLOGÍA',
    'Insuficiencia renal no especificada': 'NEFROLOGÍA',
    'Accidente vascular encefálico agudo, no especificado como hemorrágico o isquémico': 'NEUROLOGÍA',
    'Enfermedad por virus de la inmunodeficiencia humana [VIH], resultante en enfermedades infecciosas y parasitarias': 'INFECTOLOGÍA',
    'Ocupante de automóvil lesionado por colisión con otro automóvil, camioneta o furgoneta': 'TRAUMATOLOGÍA',
    'Enfermedad alcohólica del hígado': 'HEPATOLOGÍA',
    'Ocupante de automóvil lesionado en otros accidentes de transporte, y en los no especificados': 'TRAUMATOLOGÍA',
    'Infarto cerebral': 'NEUROLOGÍA',
    'Diabetes mellitus insulinodependiente': 'ENDOCRINOLOGÍA',
    'Agresión con objeto cortante': 'TRAUMATOLOGÍA',
    'Motociclista lesionado por colisión con automóvil, camioneta o furgoneta': 'TRAUMATOLOGÍA',
    'Peatón lesionado por colisión con automóvil, camioneta o furgoneta': 'TRAUMATOLOGÍA',
    'Hipertensión esencial (primaria)': 'CARDIOLOGÍA',
    'Exposición a humos, fuegos o llamas no especificados': 'MEDICINA DE EMERGENCIA',
    'Dolor abdominal y pélvico': 'GASTROENTEROLOGÍA',
    'Edema pulmonar': 'NEUMONOLOGÍA',
    'Otros trastornos del sistema urinario': 'UROLOGÍA',
}

# Mapeo de causas de defunción en df_adultos_def
df_adultos_def['Especialidad'] = df_adultos_def['causa_defuncion'].map(mapeo_especialidades)

# Verificación de la información del DataFrame actualizado
df_adultos_def.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6049 entries, 80144 to 825571
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   anio                           6049 non-null   int64
#  1   jurisdiccion_de_residencia_id  6049 non-null   int64
#  2   provincia_nombre               6049 non-null   object
#  3   cie10_causa_id                 6049 non-null   object
#  4   causa_defuncion                6049 non-null   object
#  5   sexo_id                        6049 non-null   int64
#  6   Sexo                           6049 non-null   object
#  7   grupo_edad                     6049 non-null   object
#  8   cantidad                       6049 non-null   int64
#  9   pediatria                      6049 non-null   bool
#  10  Especialidad                   6049 non-null   object
# dtypes: bool(1), int64(4), object(6)
# memory usage: 525.7+ KB
# <ipython-input-74-ccc03cbe8c92>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_adultos_def['Especialidad'] = df_adultos_def['causa_defuncion'].map(mapeo_especialidades)

# %%
# Verificar si todas las especialidades en df_adultos_def['Especialidad'] están en la lista df_especialidades_adultos['Especialidad']
especialidades_validas = df_adultos_def['Especialidad'].isin(df_especialidades_adultos['Especialidad'])

# Filtrar las especialidades no válidas
especialidades_invalidas = df_adultos_def[~especialidades_validas]

# Imprimir el resultado
if especialidades_invalidas.empty:
    print("Todas las especialidades son válidas.")
else:
    print("Existen especialidades no válidas:")
    print(especialidades_invalidas[['causa_defuncion', 'Especialidad']])
# Out:
# Existen especialidades no válidas:
#                                           causa_defuncion  \
# 80899                Choque, no clasificado en otra parte
# 87290   Accidente de vehículo de motor o sin motor, ti...
# 91128   Ocupante de automóvil lesionado por colisión c...
# 93145                Choque, no clasificado en otra parte
# 94209   Peatón lesionado por colisión con automóvil, c...
# 95089   Ocupante de automóvil lesionado en otros accid...
# 95362   Ocupante de automóvil lesionado por colisión c...
# 97150   Ocupante de automóvil lesionado en otros accid...
# 99467   Exposición a humos, fuegos o llamas no especif...
# 101186               Choque, no clasificado en otra parte
# 103191  Motociclista lesionado por colisión con automó...
# 105687               Choque, no clasificado en otra parte
# 105869  Ocupante de automóvil lesionado en otros accid...
# 107841  Accidente de vehículo de motor o sin motor, ti...
# 108907  Motociclista lesionado por colisión con automó...
# 109997  Motociclista lesionado por colisión con automó...
# 112517               Choque, no clasificado en otra parte
# 115343  Motociclista lesionado por colisión con automó...
# 115497  Ocupante de automóvil lesionado por colisión c...
# 118500                       Agresión con objeto cortante
# 119834               Choque, no clasificado en otra parte
# 120843               Choque, no clasificado en otra parte
# 121086  Accidente de vehículo de motor o sin motor, ti...
# 121181  Accidente de vehículo de motor o sin motor, ti...
# 123904  Motociclista lesionado por colisión con automó...
# 123951                       Agresión con objeto cortante
# 128085  Ocupante de automóvil lesionado por colisión c...
# 139781  Ocupante de automóvil lesionado en otros accid...
# 144042  Peatón lesionado por colisión con automóvil, c...
# 145116                       Agresión con objeto cortante
# 145959                       Agresión con objeto cortante
# 151641  Ocupante de automóvil lesionado por colisión c...
# 152206               Choque, no clasificado en otra parte
# 154347  Accidente de vehículo de motor o sin motor, ti...
# 154500  Ocupante de automóvil lesionado por colisión c...
# 154775  Ocupante de automóvil lesionado por colisión c...
# 159107  Accidente de vehículo de motor o sin motor, ti...
# 162939  Peatón lesionado por colisión con automóvil, c...
# 169710  Accidente de vehículo de motor o sin motor, ti...
# 170456               Choque, no clasificado en otra parte
# 172801  Exposición a humos, fuegos o llamas no especif...
# 173968               Choque, no clasificado en otra parte
# 175988  Accidente de vehículo de motor o sin motor, ti...
# 176451  Motociclista lesionado por colisión con automó...
# 176612               Choque, no clasificado en otra parte
# 176638               Choque, no clasificado en otra parte
# 180530  Ocupante de automóvil lesionado en otros accid...
# 181010  Peatón lesionado por colisión con automóvil, c...
# 187618  Ocupante de automóvil lesionado por colisión c...
# 189248  Motociclista lesionado por colisión con automó...
# 194978               Choque, no clasificado en otra parte
# 195443  Ocupante de automóvil lesionado por colisión c...
# 199193  Ocupante de automóvil lesionado en otros accid...
# 201153               Choque, no clasificado en otra parte
# 201385               Choque, no clasificado en otra parte
# 201469  Accidente de vehículo de motor o sin motor, ti...
# 205473               Choque, no clasificado en otra parte
# 207466  Exposición a humos, fuegos o llamas no especif...
# 208966  Ocupante de automóvil lesionado por colisión c...
# 211096  Ocupante de automóvil lesionado en otros accid...
# 212083               Choque, no clasificado en otra parte
# 214316               Choque, no clasificado en otra parte
# 215683  Exposición a humos, fuegos o llamas no especif...
# 216930  Exposición a humos, fuegos o llamas no especif...
# 220914  Accidente de vehículo de motor o sin motor, ti...
# 220990               Choque, no clasificado en otra parte
# 225150               Choque, no clasificado en otra parte
# 227281                       Agresión con objeto cortante
# 229242  Accidente de vehículo de motor o sin motor, ti...
# 229411               Choque, no clasificado en otra parte
# 234259               Choque, no clasificado en otra parte
# 235488               Choque, no clasificado en otra parte
# 237631                       Agresión con objeto cortante
# 237978  Exposición a humos, fuegos o llamas no especif...
# 242406               Choque, no clasificado en otra parte
# 245085               Choque, no clasificado en otra parte
# 254209  Ocupante de automóvil lesionado por colisión c...
# 261038  Ocupante de automóvil lesionado en otros accid...
# 268563  Accidente de vehículo de motor o sin motor, ti...
# 271328               Choque, no clasificado en otra parte
# 271769               Choque, no clasificado en otra parte
# 278213  Accidente de vehículo de motor o sin motor, ti...
# 280229               Choque, no clasificado en otra parte
# 298564               Choque, no clasificado en otra parte
# 301311               Choque, no clasificado en otra parte
# 301509               Choque, no clasificado en otra parte
# 310782  Peatón lesionado por colisión con automóvil, c...
# 318641               Choque, no clasificado en otra parte
# 319016               Choque, no clasificado en otra parte
# 320088               Choque, no clasificado en otra parte
# 325343  Accidente de vehículo de motor o sin motor, ti...
# 328652               Choque, no clasificado en otra parte
# 328814               Choque, no clasificado en otra parte
# 329235  Motociclista lesionado por colisión con automó...
# 330966               Choque, no clasificado en otra parte
# 334449  Peatón lesionado por colisión con automóvil, c...
# 336530                       Agresión con objeto cortante
# 338535  Ocupante de automóvil lesionado por colisión c...
# 348700               Choque, no clasificado en otra parte
# 349649  Accidente de vehículo de motor o sin motor, ti...
# 357064  Ocupante de automóvil lesionado por colisión c...
# 360272               Choque, no clasificado en otra parte
# 360679               Choque, no clasificado en otra parte
# 365890               Choque, no clasificado en otra parte
# 366622  Ocupante de automóvil lesionado en otros accid...
# 366841  Accidente de vehículo de motor o sin motor, ti...
# 369121               Choque, no clasificado en otra parte
# 369303  Ocupante de automóvil lesionado por colisión c...
# 370288  Ocupante de automóvil lesionado por colisión c...
# 378406  Ocupante de automóvil lesionado en otros accid...
# 390682               Choque, no clasificado en otra parte
# 391490               Choque, no clasificado en otra parte
# 410317               Choque, no clasificado en otra parte
# 410922  Peatón lesionado por colisión con automóvil, c...
# 411546  Peatón lesionado por colisión con automóvil, c...
# 412867  Exposición a humos, fuegos o llamas no especif...
# 418066               Choque, no clasificado en otra parte
# 419238               Choque, no clasificado en otra parte
# 420172               Choque, no clasificado en otra parte
# 429361               Choque, no clasificado en otra parte
# 433684  Ocupante de automóvil lesionado por colisión c...
# 438985               Choque, no clasificado en otra parte
# 441114               Choque, no clasificado en otra parte
# 445585               Choque, no clasificado en otra parte
# 445864  Motociclista lesionado por colisión con automó...
# 446298  Accidente de vehículo de motor o sin motor, ti...
# 447213               Choque, no clasificado en otra parte
# 448944               Choque, no clasificado en otra parte
# 449176               Choque, no clasificado en otra parte
# 449261  Motociclista lesionado por colisión con automó...
# 458640                       Agresión con objeto cortante
# 459866               Choque, no clasificado en otra parte
# 461735               Choque, no clasificado en otra parte
# 465372               Choque, no clasificado en otra parte
# 465829               Choque, no clasificado en otra parte
# 467547               Choque, no clasificado en otra parte
# 470644               Choque, no clasificado en otra parte
# 473179               Choque, no clasificado en otra parte
# 480945  Peatón lesionado por colisión con automóvil, c...
# 482307  Accidente de vehículo de motor o sin motor, ti...
# 496300               Choque, no clasificado en otra parte
# 508732               Choque, no clasificado en otra parte
# 525736               Choque, no clasificado en otra parte
# 535683               Choque, no clasificado en otra parte
# 537668               Choque, no clasificado en otra parte
# 538598               Choque, no clasificado en otra parte
# 539135               Choque, no clasificado en otra parte
# 547714               Choque, no clasificado en otra parte
# 556451  Accidente de vehículo de motor o sin motor, ti...
# 565274               Choque, no clasificado en otra parte
# 565626               Choque, no clasificado en otra parte
# 568042               Choque, no clasificado en otra parte
# 576863               Choque, no clasificado en otra parte
# 578702               Choque, no clasificado en otra parte
# 585679  Ocupante de automóvil lesionado en otros accid...
# 585912               Choque, no clasificado en otra parte
# 587477               Choque, no clasificado en otra parte
# 591918                       Agresión con objeto cortante
# 594558               Choque, no clasificado en otra parte
# 596100               Choque, no clasificado en otra parte
# 596631               Choque, no clasificado en otra parte
# 597876               Choque, no clasificado en otra parte
# 598074               Choque, no clasificado en otra parte
# 605691               Choque, no clasificado en otra parte
# 605721               Choque, no clasificado en otra parte
# 613449               Choque, no clasificado en otra parte
# 615656               Choque, no clasificado en otra parte
# 619442               Choque, no clasificado en otra parte
# 622046               Choque, no clasificado en otra parte
# 633613  Ocupante de automóvil lesionado en otros accid...
# 673014               Choque, no clasificado en otra parte
# 673643               Choque, no clasificado en otra parte
# 673702               Choque, no clasificado en otra parte
# 674326               Choque, no clasificado en otra parte
# 674380               Choque, no clasificado en otra parte
# 674581               Choque, no clasificado en otra parte
# 675261               Choque, no clasificado en otra parte
# 676254               Choque, no clasificado en otra parte
# 712666  Ocupante de automóvil lesionado por colisión c...
# 727037  Exposición a humos, fuegos o llamas no especif...
# 731680               Choque, no clasificado en otra parte
# 731691  Accidente de vehículo de motor o sin motor, ti...
# 732493               Choque, no clasificado en otra parte
# 733022               Choque, no clasificado en otra parte
# 733178               Choque, no clasificado en otra parte
# 735300               Choque, no clasificado en otra parte
# 752215               Choque, no clasificado en otra parte
# 754765  Peatón lesionado por colisión con automóvil, c...
# 754927               Choque, no clasificado en otra parte
# 761196               Choque, no clasificado en otra parte
# 761245               Choque, no clasificado en otra parte
# 761377               Choque, no clasificado en otra parte
# 762036               Choque, no clasificado en otra parte
# 762308               Choque, no clasificado en otra parte
# 762714               Choque, no clasificado en otra parte
# 763850               Choque, no clasificado en otra parte
# 764345               Choque, no clasificado en otra parte
# 766000                       Agresión con objeto cortante
# 781443               Choque, no clasificado en otra parte
# 789977               Choque, no clasificado en otra parte
# 790729               Choque, no clasificado en otra parte
# 790736               Choque, no clasificado en otra parte
# 791013  Ocupante de automóvil lesionado en otros accid...
# 792240               Choque, no clasificado en otra parte
# 793264               Choque, no clasificado en otra parte
# 799358               Choque, no clasificado en otra parte
# 801155               Choque, no clasificado en otra parte
# 801649               Choque, no clasificado en otra parte
# 802890               Choque, no clasificado en otra parte
# 802907  Motociclista lesionado por colisión con automó...
# 803956  Accidente de vehículo de motor o sin motor, ti...
# 806379               Choque, no clasificado en otra parte
# 806995               Choque, no clasificado en otra parte
# 809316               Choque, no clasificado en otra parte
# 810212  Peatón lesionado por colisión con automóvil, c...
# 811099                       Agresión con objeto cortante
# 811675               Choque, no clasificado en otra parte
# 816117               Choque, no clasificado en otra parte
#
#                   Especialidad
# 80899   MEDICINA DE EMERGENCIA
# 87290            TRAUMATOLOGÍA
# 91128            TRAUMATOLOGÍA
# 93145   MEDICINA DE EMERGENCIA
# 94209            TRAUMATOLOGÍA
# 95089            TRAUMATOLOGÍA
# 95362            TRAUMATOLOGÍA
# 97150            TRAUMATOLOGÍA
# 99467   MEDICINA DE EMERGENCIA
# 101186  MEDICINA DE EMERGENCIA
# 103191           TRAUMATOLOGÍA
# 105687  MEDICINA DE EMERGENCIA
# 105869           TRAUMATOLOGÍA
# 107841           TRAUMATOLOGÍA
# 108907           TRAUMATOLOGÍA
# 109997           TRAUMATOLOGÍA
# 112517  MEDICINA DE EMERGENCIA
# 115343           TRAUMATOLOGÍA
# 115497           TRAUMATOLOGÍA
# 118500           TRAUMATOLOGÍA
# 119834  MEDICINA DE EMERGENCIA
# 120843  MEDICINA DE EMERGENCIA
# 121086           TRAUMATOLOGÍA
# 121181           TRAUMATOLOGÍA
# 123904           TRAUMATOLOGÍA
# 123951           TRAUMATOLOGÍA
# 128085           TRAUMATOLOGÍA
# 139781           TRAUMATOLOGÍA
# 144042           TRAUMATOLOGÍA
# 145116           TRAUMATOLOGÍA
# 145959           TRAUMATOLOGÍA
# 151641           TRAUMATOLOGÍA
# 152206  MEDICINA DE EMERGENCIA
# 154347           TRAUMATOLOGÍA
# 154500           TRAUMATOLOGÍA
# 154775           TRAUMATOLOGÍA
# 159107           TRAUMATOLOGÍA
# 162939           TRAUMATOLOGÍA
# 169710           TRAUMATOLOGÍA
# 170456  MEDICINA DE EMERGENCIA
# 172801  MEDICINA DE EMERGENCIA
# 173968  MEDICINA DE EMERGENCIA
# 175988           TRAUMATOLOGÍA
# 176451           TRAUMATOLOGÍA
# 176612  MEDICINA DE EMERGENCIA
# 176638  MEDICINA DE EMERGENCIA
# 180530           TRAUMATOLOGÍA
# 181010           TRAUMATOLOGÍA
# 187618           TRAUMATOLOGÍA
# 189248           TRAUMATOLOGÍA
# 194978  MEDICINA DE EMERGENCIA
# 195443           TRAUMATOLOGÍA
# 199193           TRAUMATOLOGÍA
# 201153  MEDICINA DE EMERGENCIA
# 201385  MEDICINA DE EMERGENCIA
# 201469           TRAUMATOLOGÍA
# 205473  MEDICINA DE EMERGENCIA
# 207466  MEDICINA DE EMERGENCIA
# 208966           TRAUMATOLOGÍA
# 211096           TRAUMATOLOGÍA
# 212083  MEDICINA DE EMERGENCIA
# 214316  MEDICINA DE EMERGENCIA
# 215683  MEDICINA DE EMERGENCIA
# 216930  MEDICINA DE EMERGENCIA
# 220914           TRAUMATOLOGÍA
# 220990  MEDICINA DE EMERGENCIA
# 225150  MEDICINA DE EMERGENCIA
# 227281           TRAUMATOLOGÍA
# 229242           TRAUMATOLOGÍA
# 229411  MEDICINA DE EMERGENCIA
# 234259  MEDICINA DE EMERGENCIA
# 235488  MEDICINA DE EMERGENCIA
# 237631           TRAUMATOLOGÍA
# 237978  MEDICINA DE EMERGENCIA
# 242406  MEDICINA DE EMERGENCIA
# 245085  MEDICINA DE EMERGENCIA
# 254209           TRAUMATOLOGÍA
# 261038           TRAUMATOLOGÍA
# 268563           TRAUMATOLOGÍA
# 271328  MEDICINA DE EMERGENCIA
# 271769  MEDICINA DE EMERGENCIA
# 278213           TRAUMATOLOGÍA
# 280229  MEDICINA DE EMERGENCIA
# 298564  MEDICINA DE EMERGENCIA
# 301311  MEDICINA DE EMERGENCIA
# 301509  MEDICINA DE EMERGENCIA
# 310782           TRAUMATOLOGÍA
# 318641  MEDICINA DE EMERGENCIA
# 319016  MEDICINA DE EMERGENCIA
# 320088  MEDICINA DE EMERGENCIA
# 325343           TRAUMATOLOGÍA
# 328652  MEDICINA DE EMERGENCIA
# 328814  MEDICINA DE EMERGENCIA
# 329235           TRAUMATOLOGÍA
# 330966  MEDICINA DE EMERGENCIA
# 334449           TRAUMATOLOGÍA
# 336530           TRAUMATOLOGÍA
# 338535           TRAUMATOLOGÍA
# 348700  MEDICINA DE EMERGENCIA
# 349649           TRAUMATOLOGÍA
# 357064           TRAUMATOLOGÍA
# 360272  MEDICINA DE EMERGENCIA
# 360679  MEDICINA DE EMERGENCIA
# 365890  MEDICINA DE EMERGENCIA
# 366622           TRAUMATOLOGÍA
# 366841           TRAUMATOLOGÍA
# 369121  MEDICINA DE EMERGENCIA
# 369303           TRAUMATOLOGÍA
# 370288           TRAUMATOLOGÍA
# 378406           TRAUMATOLOGÍA
# 390682  MEDICINA DE EMERGENCIA
# 391490  MEDICINA DE EMERGENCIA
# 410317  MEDICINA DE EMERGENCIA
# 410922           TRAUMATOLOGÍA
# 411546           TRAUMATOLOGÍA
# 412867  MEDICINA DE EMERGENCIA
# 418066  MEDICINA DE EMERGENCIA
# 419238  MEDICINA DE EMERGENCIA
# 420172  MEDICINA DE EMERGENCIA
# 429361  MEDICINA DE EMERGENCIA
# 433684           TRAUMATOLOGÍA
# 438985  MEDICINA DE EMERGENCIA
# 441114  MEDICINA DE EMERGENCIA
# 445585  MEDICINA DE EMERGENCIA
# 445864           TRAUMATOLOGÍA
# 446298           TRAUMATOLOGÍA
# 447213  MEDICINA DE EMERGENCIA
# 448944  MEDICINA DE EMERGENCIA
# 449176  MEDICINA DE EMERGENCIA
# 449261           TRAUMATOLOGÍA
# 458640           TRAUMATOLOGÍA
# 459866  MEDICINA DE EMERGENCIA
# 461735  MEDICINA DE EMERGENCIA
# 465372  MEDICINA DE EMERGENCIA
# 465829  MEDICINA DE EMERGENCIA
# 467547  MEDICINA DE EMERGENCIA
# 470644  MEDICINA DE EMERGENCIA
# 473179  MEDICINA DE EMERGENCIA
# 480945           TRAUMATOLOGÍA
# 482307           TRAUMATOLOGÍA
# 496300  MEDICINA DE EMERGENCIA
# 508732  MEDICINA DE EMERGENCIA
# 525736  MEDICINA DE EMERGENCIA
# 535683  MEDICINA DE EMERGENCIA
# 537668  MEDICINA DE EMERGENCIA
# 538598  MEDICINA DE EMERGENCIA
# 539135  MEDICINA DE EMERGENCIA
# 547714  MEDICINA DE EMERGENCIA
# 556451           TRAUMATOLOGÍA
# 565274  MEDICINA DE EMERGENCIA
# 565626  MEDICINA DE EMERGENCIA
# 568042  MEDICINA DE EMERGENCIA
# 576863  MEDICINA DE EMERGENCIA
# 578702  MEDICINA DE EMERGENCIA
# 585679           TRAUMATOLOGÍA
# 585912  MEDICINA DE EMERGENCIA
# 587477  MEDICINA DE EMERGENCIA
# 591918           TRAUMATOLOGÍA
# 594558  MEDICINA DE EMERGENCIA
# 596100  MEDICINA DE EMERGENCIA
# 596631  MEDICINA DE EMERGENCIA
# 597876  MEDICINA DE EMERGENCIA
# 598074  MEDICINA DE EMERGENCIA
# 605691  MEDICINA DE EMERGENCIA
# 605721  MEDICINA DE EMERGENCIA
# 613449  MEDICINA DE EMERGENCIA
# 615656  MEDICINA DE EMERGENCIA
# 619442  MEDICINA DE EMERGENCIA
# 622046  MEDICINA DE EMERGENCIA
# 633613           TRAUMATOLOGÍA
# 673014  MEDICINA DE EMERGENCIA
# 673643  MEDICINA DE EMERGENCIA
# 673702  MEDICINA DE EMERGENCIA
# 674326  MEDICINA DE EMERGENCIA
# 674380  MEDICINA DE EMERGENCIA
# 674581  MEDICINA DE EMERGENCIA
# 675261  MEDICINA DE EMERGENCIA
# 676254  MEDICINA DE EMERGENCIA
# 712666           TRAUMATOLOGÍA
# 727037  MEDICINA DE EMERGENCIA
# 731680  MEDICINA DE EMERGENCIA
# 731691           TRAUMATOLOGÍA
# 732493  MEDICINA DE EMERGENCIA
# 733022  MEDICINA DE EMERGENCIA
# 733178  MEDICINA DE EMERGENCIA
# 735300  MEDICINA DE EMERGENCIA
# 752215  MEDICINA DE EMERGENCIA
# 754765           TRAUMATOLOGÍA
# 754927  MEDICINA DE EMERGENCIA
# 761196  MEDICINA DE EMERGENCIA
# 761245  MEDICINA DE EMERGENCIA
# 761377  MEDICINA DE EMERGENCIA
# 762036  MEDICINA DE EMERGENCIA
# 762308  MEDICINA DE EMERGENCIA
# 762714  MEDICINA DE EMERGENCIA
# 763850  MEDICINA DE EMERGENCIA
# 764345  MEDICINA DE EMERGENCIA
# 766000           TRAUMATOLOGÍA
# 781443  MEDICINA DE EMERGENCIA
# 789977  MEDICINA DE EMERGENCIA
# 790729  MEDICINA DE EMERGENCIA
# 790736  MEDICINA DE EMERGENCIA
# 791013           TRAUMATOLOGÍA
# 792240  MEDICINA DE EMERGENCIA
# 793264  MEDICINA DE EMERGENCIA
# 799358  MEDICINA DE EMERGENCIA
# 801155  MEDICINA DE EMERGENCIA
# 801649  MEDICINA DE EMERGENCIA
# 802890  MEDICINA DE EMERGENCIA
# 802907           TRAUMATOLOGÍA
# 803956           TRAUMATOLOGÍA
# 806379  MEDICINA DE EMERGENCIA
# 806995  MEDICINA DE EMERGENCIA
# 809316  MEDICINA DE EMERGENCIA
# 810212           TRAUMATOLOGÍA
# 811099           TRAUMATOLOGÍA
# 811675  MEDICINA DE EMERGENCIA
# 816117  MEDICINA DE EMERGENCIA

# %% [markdown]
# # **Union causas de defunción y df especialidades dada las especialidades "requeridas"**

# %% [markdown]
# Si mi objetivo es poder ver si debido a la causa de defuncion, en ambos *df_pediatria_def* y *df_adultos_def*, y dada la especialidad requerida, y viendo en los dataframes, *df_especialidades_ped* y *df_especialidades_adultos*, si dada la especialidad requerida esta disponible dada la provincia donde ocurrió la defuncion
#
# ¿Cómo deberia mergear?

# %%
print("Columnas de df_pediatria_def:")
print(df_pediatria_def.columns)

print("\nColumnas de df_especialidades_ped:")
print(df_especialidades_ped.columns)
# Out:
# Columnas de df_pediatria_def:
# Index(['anio', 'jurisdiccion_de_residencia_id', 'provincia_nombre',
#        'cie10_causa_id', 'causa_defuncion', 'sexo_id', 'Sexo', 'grupo_edad',
#        'cantidad', 'pediatria', 'Especialidad'],
#       dtype='object')
#
# Columnas de df_especialidades_ped:
# Index(['Especialidad', 'esp_bsas', 'esp_cba', 'esp_caba', 'esp_mendoza',
#        'esp_santafe', 'esp_catamarca', 'esp_formosa', 'esp_entrerios',
#        'esp_corrientes', 'esp_jujuy', 'esp_larioja', 'esp_neuquen',
#        'esp_rionegro', 'esp_salta', 'esp_sanluis', 'esp_tierradelfuego',
#        'esp_tucuman', 'esp_chaco', 'esp_lapampa', 'esp_santacruz',
#        'esp_chubut', 'esp_sanjuan', 'esp_misiones', 'esp_santiagodelestero',
#        'especialidad_pediatria'],
#       dtype='object')

# %%
# Renombrar las columnas en df_especialidades_ped
df_especialidades_ped.rename(columns={
    'esp_bsas': 'BUENOS AIRES',
    'esp_cba': 'CÓRDOBA',
    'esp_caba': 'CIUDAD AUTÓNOMA DE BUENOS AIRES',
    'esp_mendoza': 'MENDOZA',
    'esp_santafe': 'SANTA FE',
    'esp_catamarca': 'CATAMARCA',
    'esp_formosa': 'FORMOSA',
    'esp_entrerios': 'ENTRE RÍOS',
    'esp_corrientes': 'CORRIENTES',
    'esp_jujuy': 'JUJUY',
    'esp_larioja': 'LA RIOJA',
    'esp_neuquen': 'NEUQUÉN',
    'esp_rionegro': 'RÍO NEGRO',
    'esp_salta': 'SALTA',
    'esp_sanluis': 'SAN LUIS',
    'esp_tierradelfuego': 'TIERRA DEL FUEGO, ANTÁRTIDA E ISLAS DEL ATLÁNTICO SUR',
    'esp_tucuman': 'TUCUMÁN',
    'esp_chaco': 'CHACO',
    'esp_lapampa': 'LA PAMPA',
    'esp_santacruz': 'SANTA CRUZ',
    'esp_chubut': 'CHUBUT',
    'esp_sanjuan': 'SAN JUAN',
    'esp_misiones': 'MISIONES',
    'esp_santiagodelestero': 'SANTIAGO DEL ESTERO'
}, inplace=True)


df_pediatria_def.drop(columns=['pediatria'], inplace=True)
df_especialidades_ped.drop(columns=['especialidad_pediatria'], inplace=True)
# Out:
# <ipython-input-77-63a02d2b54d6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_especialidades_ped.rename(columns={
# <ipython-input-77-63a02d2b54d6>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pediatria_def.drop(columns=['pediatria'], inplace=True)
# <ipython-input-77-63a02d2b54d6>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_especialidades_ped.drop(columns=['especialidad_pediatria'], inplace=True)

# %%
df_pediatria_def['provincia_nombre'].unique()
# Out:
# array(['Santiago del Estero', 'La Rioja', 'Buenos Aires', 'Corrientes',
#        'Santa Fe', 'San Juan', 'Córdoba', 'Salta', 'Tucumán', 'Mendoza',
#        'La Pampa', 'Chaco', 'Neuquén', 'Chubut',
#        'Ciudad Autónoma de Buenos Aires', 'Entre Ríos', 'Formosa',
#        'Río Negro', 'Catamarca', 'Misiones', 'Jujuy',
#        'Tierra del Fuego, Antártida e Islas del Atlántico Sur',
#        'San Luis', 'Santa Cruz'], dtype=object)

# %%
# Convertir los nombres de las provincias a mayúsculas en df_pediatria_def
df_pediatria_def.loc[:, 'provincia_nombre'] = df_pediatria_def['provincia_nombre'].str.upper()

# Verificar las primeras filas del DataFrame después de la conversión
df_pediatria_def['provincia_nombre'].unique()
# Out:
# array(['SANTIAGO DEL ESTERO', 'LA RIOJA', 'BUENOS AIRES', 'CORRIENTES',
#        'SANTA FE', 'SAN JUAN', 'CÓRDOBA', 'SALTA', 'TUCUMÁN', 'MENDOZA',
#        'LA PAMPA', 'CHACO', 'NEUQUÉN', 'CHUBUT',
#        'CIUDAD AUTÓNOMA DE BUENOS AIRES', 'ENTRE RÍOS', 'FORMOSA',
#        'RÍO NEGRO', 'CATAMARCA', 'MISIONES', 'JUJUY',
#        'TIERRA DEL FUEGO, ANTÁRTIDA E ISLAS DEL ATLÁNTICO SUR',
#        'SAN LUIS', 'SANTA CRUZ'], dtype=object)

# %%
# Verificar si hay valores nulos en alguna columna
valores_nulos = df_pediatria_def.isnull().sum()

# Mostrar el conteo de valores nulos por columna
print(valores_nulos)

print(df_especialidades_ped.isnull().sum())
# Out:
# anio                             0
# jurisdiccion_de_residencia_id    0
# provincia_nombre                 0
# cie10_causa_id                   0
# causa_defuncion                  0
# sexo_id                          0
# Sexo                             0
# grupo_edad                       0
# cantidad                         0
# Especialidad                     0
# dtype: int64
# Especialidad                                             0
# BUENOS AIRES                                             0
# CÓRDOBA                                                  0
# CIUDAD AUTÓNOMA DE BUENOS AIRES                          0
# MENDOZA                                                  0
# SANTA FE                                                 0
# CATAMARCA                                                0
# FORMOSA                                                  0
# ENTRE RÍOS                                               0
# CORRIENTES                                               0
# JUJUY                                                    0
# LA RIOJA                                                 0
# NEUQUÉN                                                  0
# RÍO NEGRO                                                0
# SALTA                                                    0
# SAN LUIS                                                 0
# TIERRA DEL FUEGO, ANTÁRTIDA E ISLAS DEL ATLÁNTICO SUR    0
# TUCUMÁN                                                  0
# CHACO                                                    0
# LA PAMPA                                                 0
# SANTA CRUZ                                               0
# CHUBUT                                                   0
# SAN JUAN                                                 0
# MISIONES                                                 0
# SANTIAGO DEL ESTERO                                      0
# dtype: int64

# %%
# Convertir las cantidades a números enteros
df_especialidades_ped = df_especialidades_ped.astype({'BUENOS AIRES': int,
                                                              'CÓRDOBA': int,
                                                              'CIUDAD AUTÓNOMA DE BUENOS AIRES': int,
                                                              'MENDOZA': int,
                                                              'SANTA FE': int,
                                                              'CATAMARCA': int,
                                                              'FORMOSA': int,
                                                              'ENTRE RÍOS': int,
                                                              'CORRIENTES': int,
                                                              'JUJUY': int,
                                                              'LA RIOJA': int,
                                                              'NEUQUÉN': int,
                                                              'RÍO NEGRO': int,
                                                              'SALTA': int,
                                                              'SAN LUIS': int,
                                                              'TIERRA DEL FUEGO, ANTÁRTIDA E ISLAS DEL ATLÁNTICO SUR': int,
                                                              'TUCUMÁN': int,
                                                              'CHACO': int,
                                                              'LA PAMPA': int,
                                                              'SANTA CRUZ': int,
                                                              'CHUBUT': int,
                                                              'SAN JUAN': int,
                                                              'MISIONES': int,
                                                              'SANTIAGO DEL ESTERO': int})

# Verificar la conversión
print(df_especialidades_ped.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23 entries, 1 to 80
# Data columns (total 25 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Especialidad                                           23 non-null     object
#  1   BUENOS AIRES                                           23 non-null     int64
#  2   CÓRDOBA                                                23 non-null     int64
#  3   CIUDAD AUTÓNOMA DE BUENOS AIRES                        23 non-null     int64
#  4   MENDOZA                                                23 non-null     int64
#  5   SANTA FE                                               23 non-null     int64
#  6   CATAMARCA                                              23 non-null     int64
#  7   FORMOSA                                                23 non-null     int64
#  8   ENTRE RÍOS                                             23 non-null     int64
#  9   CORRIENTES                                             23 non-null     int64
#  10  JUJUY                                                  23 non-null     int64
#  11  LA RIOJA                                               23 non-null     int64
#  12  NEUQUÉN                                                23 non-null     int64
#  13  RÍO NEGRO                                              23 non-null     int64
#  14  SALTA                                                  23 non-null     int64
#  15  SAN LUIS                                               23 non-null     int64
#  16  TIERRA DEL FUEGO, ANTÁRTIDA E ISLAS DEL ATLÁNTICO SUR  23 non-null     int64
#  17  TUCUMÁN                                                23 non-null     int64
#  18  CHACO                                                  23 non-null     int64
#  19  LA PAMPA                                               23 non-null     int64
#  20  SANTA CRUZ                                             23 non-null     int64
#  21  CHUBUT                                                 23 non-null     int64
#  22  SAN JUAN                                               23 non-null     int64
#  23  MISIONES                                               23 non-null     int64
#  24  SANTIAGO DEL ESTERO                                    23 non-null     int64
# dtypes: int64(24), object(1)
# memory usage: 4.7+ KB
# None

# %%
# Crear un diccionario con las especialidades como claves y sus disponibilidades por provincia como valores
especialidades_disponibles = df_especialidades_ped.set_index('Especialidad').to_dict(orient='index')

# Función para verificar la disponibilidad de una especialidad en una provincia
def especialidad_disponible(row):
    especialidad = row['Especialidad']
    provincia = row['provincia_nombre']

    if especialidad in especialidades_disponibles:
        disponibilidad_provincia = especialidades_disponibles[especialidad].get(provincia, 0)
        if disponibilidad_provincia > 0:  # Verifica que la disponibilidad sea mayor a cero
            return 1

    return 0

# Aplicar la función a cada fila del DataFrame y crear la nueva columna 'especialidad_disponible'
df_pediatria_def['especialidad_disponible'] = df_pediatria_def.apply(especialidad_disponible, axis=1)

# Crear un DataFrame con las columnas requeridas
df_provincia_causa = df_pediatria_def[['provincia_nombre', 'causa_defuncion', 'Especialidad', 'especialidad_disponible']]
# Out:
# <ipython-input-82-d74368d3647b>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pediatria_def['especialidad_disponible'] = df_pediatria_def.apply(especialidad_disponible, axis=1)

# %%
df_pediatria_def.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 355 entries, 376 to 80025
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   anio                           355 non-null    int64
#  1   jurisdiccion_de_residencia_id  355 non-null    int64
#  2   provincia_nombre               355 non-null    object
#  3   cie10_causa_id                 355 non-null    object
#  4   causa_defuncion                355 non-null    object
#  5   sexo_id                        355 non-null    int64
#  6   Sexo                           355 non-null    object
#  7   grupo_edad                     355 non-null    object
#  8   cantidad                       355 non-null    int64
#  9   Especialidad                   355 non-null    object
#  10  especialidad_disponible        355 non-null    int64
# dtypes: int64(5), object(6)
# memory usage: 33.3+ KB

# %% [markdown]
# el valor 0 significa "especialidad no disponible" y el valor 1 "especialidad disponible". Esto significa que, si el valor en esa columna es 0, indica que la especialidad requerida para la provincia donde ocurrió la muerte no está disponible en la lista de especialidades pediátricas proporcionada en el DataFrame df_especialidades_ped. Por otro lado, si el valor es 1, significa que la especialidad sí está disponible en esa provincia.

# %% [markdown]
# Vamos a hacer lo mismo con *df_adultos_def *y *df_especialidad_adultos*:

# %%
df_adultos_def.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6049 entries, 80144 to 825571
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   anio                           6049 non-null   int64
#  1   jurisdiccion_de_residencia_id  6049 non-null   int64
#  2   provincia_nombre               6049 non-null   object
#  3   cie10_causa_id                 6049 non-null   object
#  4   causa_defuncion                6049 non-null   object
#  5   sexo_id                        6049 non-null   int64
#  6   Sexo                           6049 non-null   object
#  7   grupo_edad                     6049 non-null   object
#  8   cantidad                       6049 non-null   int64
#  9   pediatria                      6049 non-null   bool
#  10  Especialidad                   6049 non-null   object
# dtypes: bool(1), int64(4), object(6)
# memory usage: 525.7+ KB

# %%
df_adultos_def['provincia_nombre'].unique()
# Out:
# array(['Mendoza', 'Chaco', 'Río Negro', 'Tucumán', 'Jujuy', 'Corrientes',
#        'Córdoba', 'Santa Fe', 'Buenos Aires', 'Santiago del Estero',
#        'Misiones', 'Ciudad Autónoma de Buenos Aires', 'Catamarca',
#        'Chubut', 'Neuquén', 'Entre Ríos', 'San Luis', 'Salta', 'San Juan',
#        'La Rioja',
#        'Tierra del Fuego, Antártida e Islas del Atlántico Sur', 'Formosa',
#        'La Pampa', 'Santa Cruz'], dtype=object)

# %%
# Verificar si hay valores nulos en la columna 'provincia_nombre' del DataFrame df_adultos_def
valores_nulos = df_adultos_def['provincia_nombre'].isnull().sum()

# Imprimir el resultado
print("Cantidad de valores nulos en 'provincia_nombre':", valores_nulos)
# Out:
# Cantidad de valores nulos en 'provincia_nombre': 0

# %%
# Renombrar las columnas en df_especialidades_ped
df_especialidades_adultos.rename(columns={
    'esp_bsas': 'BUENOS AIRES',
    'esp_cba': 'CÓRDOBA',
    'esp_caba': 'CIUDAD AUTÓNOMA DE BUENOS AIRES',
    'esp_mendoza': 'MENDOZA',
    'esp_santafe': 'SANTA FE',
    'esp_catamarca': 'CATAMARCA',
    'esp_formosa': 'FORMOSA',
    'esp_entrerios': 'ENTRE RÍOS',
    'esp_corrientes': 'CORRIENTES',
    'esp_jujuy': 'JUJUY',
    'esp_larioja': 'LA RIOJA',
    'esp_neuquen': 'NEUQUÉN',
    'esp_rionegro': 'RÍO NEGRO',
    'esp_salta': 'SALTA',
    'esp_sanluis': 'SAN LUIS',
    'esp_tierradelfuego': 'TIERRA DEL FUEGO, ANTÁRTIDA E ISLAS DEL ATLÁNTICO SUR',
    'esp_tucuman': 'TUCUMÁN',
    'esp_chaco': 'CHACO',
    'esp_lapampa': 'LA PAMPA',
    'esp_santacruz': 'SANTA CRUZ',
    'esp_chubut': 'CHUBUT',
    'esp_sanjuan': 'SAN JUAN',
    'esp_misiones': 'MISIONES',
    'esp_santiagodelestero': 'SANTIAGO DEL ESTERO'
}, inplace=True)


df_adultos_def.drop(columns=['pediatria'], inplace=True)
df_especialidades_adultos.drop(columns=['especialidad_pediatria'], inplace=True)
# Out:
# <ipython-input-87-cd13a5cb09c1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_especialidades_adultos.rename(columns={
# <ipython-input-87-cd13a5cb09c1>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_adultos_def.drop(columns=['pediatria'], inplace=True)
# <ipython-input-87-cd13a5cb09c1>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_especialidades_adultos.drop(columns=['especialidad_pediatria'], inplace=True)

# %%
# Convertir las cantidades a números enteros
df_especialidades_adultos = df_especialidades_adultos.astype({'BUENOS AIRES': int,
                                                              'CÓRDOBA': int,
                                                              'CIUDAD AUTÓNOMA DE BUENOS AIRES': int,
                                                              'MENDOZA': int,
                                                              'SANTA FE': int,
                                                              'CATAMARCA': int,
                                                              'FORMOSA': int,
                                                              'ENTRE RÍOS': int,
                                                              'CORRIENTES': int,
                                                              'JUJUY': int,
                                                              'LA RIOJA': int,
                                                              'NEUQUÉN': int,
                                                              'RÍO NEGRO': int,
                                                              'SALTA': int,
                                                              'SAN LUIS': int,
                                                              'TIERRA DEL FUEGO, ANTÁRTIDA E ISLAS DEL ATLÁNTICO SUR': int,
                                                              'TUCUMÁN': int,
                                                              'CHACO': int,
                                                              'LA PAMPA': int,
                                                              'SANTA CRUZ': int,
                                                              'CHUBUT': int,
                                                              'SAN JUAN': int,
                                                              'MISIONES': int,
                                                              'SANTIAGO DEL ESTERO': int})

# Verificar la conversión
print(df_especialidades_adultos.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61 entries, 0 to 83
# Data columns (total 25 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Especialidad                                           61 non-null     object
#  1   BUENOS AIRES                                           61 non-null     int64
#  2   CÓRDOBA                                                61 non-null     int64
#  3   CIUDAD AUTÓNOMA DE BUENOS AIRES                        61 non-null     int64
#  4   MENDOZA                                                61 non-null     int64
#  5   SANTA FE                                               61 non-null     int64
#  6   CATAMARCA                                              61 non-null     int64
#  7   FORMOSA                                                61 non-null     int64
#  8   ENTRE RÍOS                                             61 non-null     int64
#  9   CORRIENTES                                             61 non-null     int64
#  10  JUJUY                                                  61 non-null     int64
#  11  LA RIOJA                                               61 non-null     int64
#  12  NEUQUÉN                                                61 non-null     int64
#  13  RÍO NEGRO                                              61 non-null     int64
#  14  SALTA                                                  61 non-null     int64
#  15  SAN LUIS                                               61 non-null     int64
#  16  TIERRA DEL FUEGO, ANTÁRTIDA E ISLAS DEL ATLÁNTICO SUR  61 non-null     int64
#  17  TUCUMÁN                                                61 non-null     int64
#  18  CHACO                                                  61 non-null     int64
#  19  LA PAMPA                                               61 non-null     int64
#  20  SANTA CRUZ                                             61 non-null     int64
#  21  CHUBUT                                                 61 non-null     int64
#  22  SAN JUAN                                               61 non-null     int64
#  23  MISIONES                                               61 non-null     int64
#  24  SANTIAGO DEL ESTERO                                    61 non-null     int64
# dtypes: int64(24), object(1)
# memory usage: 12.4+ KB
# None

# %%
# Convertir los nombres de las provincias a mayúsculas en df_adultos_def
df_adultos_def.loc[:, 'provincia_nombre'] = df_adultos_def['provincia_nombre'].str.upper()

# Crear un diccionario con las especialidades como claves y sus disponibilidades por provincia como valores para adultos
especialidades_disponibles_adultos = df_especialidades_adultos.set_index('Especialidad').to_dict(orient='index')

# Función para verificar la disponibilidad de una especialidad en una provincia para adultos
def especialidad_disponible_adultos(row):
    especialidad = row['Especialidad']
    provincia = row['provincia_nombre']

    if especialidad in especialidades_disponibles_adultos:
        disponibilidad_provincia = especialidades_disponibles_adultos[especialidad].get(provincia, 0)
        if disponibilidad_provincia > 0:  # Verifica que la disponibilidad sea mayor a cero
            return 1

    return 0

# Aplicar la función a cada fila del DataFrame y crear la nueva columna 'especialidad_disponible' para adultos
df_adultos_def['especialidad_disponible'] = df_adultos_def.apply(especialidad_disponible_adultos, axis=1)

# Crear un DataFrame con las columnas requeridas para adultos
df_provincia_causa_adultos = df_adultos_def[['provincia_nombre', 'causa_defuncion', 'Especialidad', 'especialidad_disponible']]
os = df_adultos_def[['provincia_nombre', 'causa_defuncion', 'Especialidad', 'especialidad_disponible']]
# Out:
# <ipython-input-89-a362f14e2767>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_adultos_def['especialidad_disponible'] = df_adultos_def.apply(especialidad_disponible_adultos, axis=1)

# %%
df_adultos_def.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6049 entries, 80144 to 825571
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   anio                           6049 non-null   int64
#  1   jurisdiccion_de_residencia_id  6049 non-null   int64
#  2   provincia_nombre               6049 non-null   object
#  3   cie10_causa_id                 6049 non-null   object
#  4   causa_defuncion                6049 non-null   object
#  5   sexo_id                        6049 non-null   int64
#  6   Sexo                           6049 non-null   object
#  7   grupo_edad                     6049 non-null   object
#  8   cantidad                       6049 non-null   int64
#  9   Especialidad                   6049 non-null   object
#  10  especialidad_disponible        6049 non-null   int64
# dtypes: int64(5), object(6)
# memory usage: 567.1+ KB

# %%
df_adultos_def['especialidad_disponible'].unique()
# Out:
# array([1, 0])

# %%
df_pediatria_def['especialidad_disponible'].unique()
# Out:
# array([1, 0])

# %%
# Suponiendo que df_pediatria_def ya contiene los datos adecuados filtrados por Chaco y pediatría
# Filtrar por Chaco y pediatría
df_chaco_pediatricas = df_pediatria_def[(df_pediatria_def['provincia_nombre'] == 'CHACO')]

# Contar las muertes por cada causa
muertes_por_causa = df_chaco_pediatricas.groupby('causa_defuncion')['cantidad'].sum().reset_index()

# Ordenar de forma descendente por cantidad de muertes y tomar las 10 primeras
top_10_muertes_chaco_pediatricas = muertes_por_causa.sort_values(by='cantidad', ascending=False).head(10)

# Mostrar el resultado
print(top_10_muertes_chaco_pediatricas)
# Out:
#                                      causa_defuncion  cantidad
# 7  Otras causas mal definidas y las no especifica...        10
# 5                Neumonía, organismo no especificado         8
# 4  Insuficiencia respiratoria, no clasificada en ...         2
# 6                                       Otras Sepsis         2
# 0  Cirugía y otros procedimientos quirúrgicos com...         1
# 1  Complicaciones y descripciones mal definidas d...         1
# 2                 Diabetes mellitus, no especificada         1
# 3                             Insuficiencia cardíaca         1
# 8                     Otros trastornos respiratorios         1
# 9                                        Peritonitis         1

# %%
# Lista de especialidades requeridas
especialidades_requeridas = [
    'PEDIATRÍA',
    'INFECTOLOGÍA INFANTIL',
    'NEUMONOLOGÍA INFANTIL',
    'GASTROENTEROLOGÍA INFANTIL',
    'CIRUGÍA INFANTIL (CIRUGÍA PEDIÁTRICA)',
    'CARDIOLOGÍA INFANTIL',
    'ENDOCRINOLOGÍA INFANTIL'
]

# Filtrar las especialidades requeridas para Chaco
especialidades_chaco = df_especialidades_ped.loc[df_especialidades_ped['Especialidad'].isin(especialidades_requeridas), 'CHACO']

print("Especialidades requeridas presentes en Chaco:")
print(especialidades_chaco)
# Out:
# Especialidades requeridas presentes en Chaco:
# 7      11
# 13      7
# 24      0
# 35      2
# 47      0
# 59      2
# 71    240
# Name: CHACO, dtype: int64

# %% [markdown]
# # **Análisis de datos finales**

# %% [markdown]
# Vamos a hacer un analisis de los datos obtenidos de ambos data frame, teniendo en cuenta que 0 son las especialidades requeridas en cierta provincia y que no estan disponibles, y 1 las especialidades que si estan diposnibles en la provincia requerida.

# %%
df_pediatria_def['especialidad_disponible'].unique()
# Out:
# array([1, 0])

# %%
# Contar la cantidad de ceros y unos en la columna 'especialidad_disponible'
conteo_especialidad_disponible = df_pediatria_def['especialidad_disponible'].value_counts()

# %% [markdown]
# Queremos analizar las especialidades no disponibles para determinar en qué provincias se necesitan más especialistas que no están disponibles, considerando el porcentaje de muertes.
#
# Luego, vamos a identificar las especialidades requeridas en general que no están disponibles.

# %%
# Calcular la cantidad total de defunciones en cada provincia
defunciones_por_provincia = df_pediatria_def.groupby('provincia_nombre')['cantidad'].sum().reset_index()

# Calcular la cantidad de defunciones donde la especialidad no está disponible en cada provincia
defunciones_sin_especialidad = df_pediatria_def[df_pediatria_def['especialidad_disponible'] == 0].groupby('provincia_nombre')['cantidad'].sum().reset_index()

# Fusionar los datos para tener la información en un solo DataFrame
provincias_df = defunciones_por_provincia.merge(defunciones_sin_especialidad, on='provincia_nombre', suffixes=('_total', '_sin_especialidad'))

# Calcular el porcentaje de defunciones sin especialidad sobre el total de defunciones en cada provincia
provincias_df['porcentaje_sin_especialidad'] = provincias_df['cantidad_sin_especialidad'] / provincias_df['cantidad_total'] * 100

# Ordenar por el porcentaje para identificar las provincias con mayores necesidades
provincias_df = provincias_df.sort_values(by='porcentaje_sin_especialidad', ascending=False)

# %%
# Calcular la cantidad total de defunciones para cada especialidad
defunciones_por_especialidad = df_pediatria_def.groupby('Especialidad')['cantidad'].sum().reset_index()

# Calcular la cantidad de defunciones donde la especialidad no está disponible para cada especialidad
defunciones_sin_especialidad_especialidad = df_pediatria_def[df_pediatria_def['especialidad_disponible'] == 0].groupby('Especialidad')['cantidad'].sum().reset_index()

# Fusionar los datos para tener la información en un solo DataFrame
especialidades_df = defunciones_por_especialidad.merge(defunciones_sin_especialidad_especialidad, on='Especialidad', suffixes=('_total', '_sin_especialidad'))

# Calcular el porcentaje de defunciones sin especialidad sobre el total de defunciones para cada especialidad
especialidades_df['porcentaje_sin_especialidad'] = especialidades_df['cantidad_sin_especialidad'] / especialidades_df['cantidad_total'] * 100

# Ordenar por el porcentaje para identificar las especialidades con mayores necesidades
especialidades_df = especialidades_df.sort_values(by='porcentaje_sin_especialidad', ascending=False)

# %%
import matplotlib.pyplot as plt

# Crear el gráfico de barras horizontales
plt.figure(figsize=(12, 8))
plt.barh(provincias_df['provincia_nombre'], provincias_df['porcentaje_sin_especialidad'], color='salmon')
plt.xlabel('Porcentaje de Defunciones sin Especialidad Disponible (%)')
plt.ylabel('Provincia')
plt.title('Porcentaje de Defunciones sin Especialidad Disponible por Provincia')
plt.gca().invert_yaxis()  # Invertir el eje y para que la provincia con mayor necesidad esté arriba
plt.show()

# %%
# Crear el gráfico de barras horizontales
plt.figure(figsize=(12, 8))
plt.barh(especialidades_df['Especialidad'], especialidades_df['porcentaje_sin_especialidad'], color='salmon')
plt.xlabel('Porcentaje de Defunciones sin Especialidad Disponible (%)')
plt.ylabel('Especialidad')
plt.title('Porcentaje de Defunciones sin Especialidad Disponible por Especialidad')
plt.gca().invert_yaxis()  # Invertir el eje y para que la especialidad con mayor necesidad esté arriba
plt.show()

# %% [markdown]
# A partir de los cálculos realizados, se generaron dos tipos de gráficos para visualizar la situación de las especialidades médicas en relación con las defunciones infantiles:
#
# * Gráfico de Porcentaje de Defunciones sin Especialidad por Provincia: Este gráfico muestra el porcentaje de defunciones en cada provincia donde la especialidad requerida no estaba disponible. Se utilizaron los datos de defunciones totales y defunciones sin especialidad por provincia para calcular este porcentaje.
#
# * Gráfico de Porcentaje de Defunciones sin Especialidad por Especialidad: En este gráfico, se presenta el porcentaje de defunciones para cada especialidad médica donde esa especialidad no estaba disponible. Se calcularon las defunciones totales y las defunciones sin especialidad por cada especialidad médica.
#
# Estos gráficos nos ayudan a identificar las provincias y las especialidades médicas con mayores necesidades de especialistas para mejorar la atención médica infantil."

# %%
# Filtrar las filas donde la especialidad no está disponible
df_especialidades_faltantes = df_pediatria_def[df_pediatria_def['especialidad_disponible'] == 0]

# Agrupar por provincia y especialidad, y contar la cantidad de muertes
especialidades_faltantes_por_provincia = df_especialidades_faltantes.groupby(['provincia_nombre', 'Especialidad']).size().reset_index(name='cantidad')

# %%
# Filtrar las especialidades faltantes solo para Tucumán
especialidades_faltantes_tucuman = especialidades_faltantes_por_provincia[especialidades_faltantes_por_provincia['provincia_nombre'] == 'TUCUMÁN']

# Mostrar las especialidades faltantes en Tucumán
print("Especialidades faltantes en Tucumán:")
print(especialidades_faltantes_tucuman)

# Repetir el proceso para cada provincia
# Por ejemplo, para Buenos Aires
especialidades_faltantes_bsas = especialidades_faltantes_por_provincia[especialidades_faltantes_por_provincia['provincia_nombre'] == 'NEUQUÉN']
print("\nEspecialidades faltantes en Neuquén:")
print(especialidades_faltantes_bsas)

# Repetir para las demás provincias
# Out:
# Especialidades faltantes en Tucumán:
# Empty DataFrame
# Columns: [provincia_nombre, Especialidad, cantidad]
# Index: []
#
# Especialidades faltantes en Neuquén:
# Empty DataFrame
# Columns: [provincia_nombre, Especialidad, cantidad]
# Index: []

# %% [markdown]
# Podemos seguir este analisis para ver que especialidades son requeridad, de acuerdo a la provincia y al porcentaje de muertes que no tienen la especialidad requerida en su provincia, ya que tener la especialidad requerida por ejemplo podría hacer que el tratamiento haya comenzado antes, debido a que no es tan simple viajar a otras provincias.

# %% [markdown]
# Ahora vamos a hacer el mismo analisis pero para el caso de los adultos.

# %%
df_pediatria_def['especialidad_disponible'].unique()
# Out:
# array([1, 0])

# %%
# Contar la cantidad de ceros y unos en la columna 'especialidad_disponible'
conteo_especialidad_disponible_adultos = df_adultos_def['especialidad_disponible'].value_counts()

# Mostrar el conteo de ceros y unos de manera más clara
print(f"Cantidad de ceros (especialidad no disponible): {conteo_especialidad_disponible_adultos[0]}")
print(f"Cantidad de unos (especialidad disponible): {conteo_especialidad_disponible_adultos[1]}")
# Out:
# Cantidad de ceros (especialidad no disponible): 253
# Cantidad de unos (especialidad disponible): 5796

# %%
# Calcular la cantidad total de defunciones en cada provincia
defunciones_por_provincia_adultos = df_adultos_def.groupby('provincia_nombre')['cantidad'].sum().reset_index()

# Calcular la cantidad de defunciones donde la especialidad no está disponible en cada provincia
defunciones_sin_especialidad_adultos = df_adultos_def[df_adultos_def['especialidad_disponible'] == 0].groupby('provincia_nombre')['cantidad'].sum().reset_index()

# Fusionar los datos para tener la información en un solo DataFrame
provincias_df_adultos = defunciones_por_provincia_adultos.merge(defunciones_sin_especialidad_adultos, on='provincia_nombre', suffixes=('_total', '_sin_especialidad'))

# Calcular el porcentaje de defunciones sin especialidad sobre el total de defunciones en cada provincia
provincias_df_adultos['porcentaje_sin_especialidad'] = provincias_df_adultos['cantidad_sin_especialidad'] / provincias_df_adultos['cantidad_total'] * 100

# Ordenar por el porcentaje para identificar las provincias con mayores necesidades
provincias_df_adultos = provincias_df_adultos.sort_values(by='porcentaje_sin_especialidad', ascending=False)

# Calcular la cantidad total de defunciones para cada especialidad
defunciones_por_especialidad_adultos = df_adultos_def.groupby('Especialidad')['cantidad'].sum().reset_index()

# Calcular la cantidad de defunciones donde la especialidad no está disponible para cada especialidad
defunciones_sin_especialidad_especialidad_adultos = df_adultos_def[df_adultos_def['especialidad_disponible'] == 0].groupby('Especialidad')['cantidad'].sum().reset_index()

# Fusionar los datos para tener la información en un solo DataFrame
especialidades_df_adultos = defunciones_por_especialidad_adultos.merge(defunciones_sin_especialidad_especialidad_adultos, on='Especialidad', suffixes=('_total', '_sin_especialidad'))

# Calcular el porcentaje de defunciones sin especialidad sobre el total de defunciones para cada especialidad
especialidades_df_adultos['porcentaje_sin_especialidad'] = especialidades_df_adultos['cantidad_sin_especialidad'] / especialidades_df_adultos['cantidad_total'] * 100

# Ordenar por el porcentaje para identificar las especialidades con mayores necesidades
especialidades_df_adultos = especialidades_df_adultos.sort_values(by='porcentaje_sin_especialidad', ascending=False)

# %%
# Crear el gráfico de barras horizontales
plt.figure(figsize=(12, 8))
plt.barh(provincias_df_adultos['provincia_nombre'], provincias_df_adultos['porcentaje_sin_especialidad'], color='salmon')
plt.xlabel('Porcentaje de Defunciones sin Especialidad Disponible (%)')
plt.ylabel('Provincia')
plt.title('Porcentaje de Defunciones sin Especialidad Disponible por Provincia (Adultos)')
plt.gca().invert_yaxis()  # Invertir el eje y para que la provincia con mayor necesidad esté arriba
plt.show()

# %%
# Crear el gráfico de barras horizontales
plt.figure(figsize=(12, 8))
plt.barh(especialidades_df_adultos['Especialidad'], especialidades_df_adultos['porcentaje_sin_especialidad'], color='salmon')
plt.xlabel('Porcentaje de Defunciones sin Especialidad Disponible (%)')
plt.ylabel('Especialidad')
plt.title('Porcentaje de Defunciones sin Especialidad Disponible por Especialidad (Adultos)')
plt.gca().invert_yaxis()  # Invertir el eje y para que la especialidad con mayor necesidad esté arriba
plt.show()

# %% [markdown]
# Los gráficos muestran el porcentaje de defunciones en adultos en cada provincia y por especialidad en las que la especialidad requerida no estaba disponible. Estos gráficos pueden ayudar a identificar áreas geográficas y especialidades médicas donde existe una mayor necesidad de profesionales de la salud o de recursos médicos.
#
# * Porcentaje de Defunciones sin Especialidad Disponible por Provincia (Adultos): Este gráfico muestra, para cada provincia, el porcentaje de defunciones en adultos donde la especialidad médica requerida no estaba disponible. Puede ayudar a identificar las provincias con mayores carencias en términos de acceso a especialidades médicas específicas para adultos, lo que podría indicar la necesidad de invertir en recursos médicos y profesionales en esas áreas.
#
# * Porcentaje de Defunciones sin Especialidad Disponible por Especialidad (Adultos): Este gráfico muestra, para cada especialidad médica, el porcentaje de defunciones en adultos donde esa especialidad no estaba disponible. Puede ayudar a identificar las especialidades médicas más necesarias pero menos disponibles en el contexto de defunciones en adultos, lo que podría guiar la planificación de recursos médicos y la formación de profesionales de la salud en áreas críticas.

# %% [markdown]
# Podemos ver que los resultados son bastante diferentes a los obtenidos en los casos pediatricos.

# %% [markdown]
# # **Analisis de mortalidad por provincia**

# %% [markdown]
# Usando los datos del df_población y df2 que es antes de filtrar las cusas de muertes, vamos a hacer un parámetro 'tasa de mortalidad' que relacione la cantidad de muertes por provincia y la población total en esa provincia.
# Al igual que antes vamos a diferenciar entre adultos y niños, también podríamos diferenciar por sexo.

# %%
df2['grupo_edad'].unique()
# Out:
# array(['01.De a 0  a 14 anios', '02.De 15 a 34 anios',
#        '03.De 35 a 54 anios', '04.De 55 a 74 anios',
#        '05.De 75 anios y mas', '06.Sin especificar'], dtype=object)

# %%
df2['anio'].unique()
# Out:
# array([2019])

# %%
# Definir los grupos de edad para adultos y pediatría
grupos_edad_adultos = ['02.De 15 a 34 anios', '03.De 35 a 54 anios', '04.De 55 a 74 anios', '05.De 75 anios y mas']
grupos_edad_ped = ['01.De a 0  a 14 anios']

# Filtrar el DataFrame original por grupos de edad para adultos y pediatría
df2_adulto = df2[df2['grupo_edad'].isin(grupos_edad_adultos)]
df2_ped = df2[df2['grupo_edad'].isin(grupos_edad_ped)]

# Mostrar información básica de los nuevos DataFrames
print("Información de df2_adulto:")
print(df2_adulto.info())

print("\nInformación de df2_ped:")
print(df2_ped.info())
# Out:
# Información de df2_adulto:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35852 entries, 80124 to 816978
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   anio                           35852 non-null  int64
#  1   jurisdiccion_de_residencia_id  35852 non-null  int64
#  2   provincia_nombre               35852 non-null  object
#  3   cie10_causa_id                 35852 non-null  object
#  4   causa_defuncion                35852 non-null  object
#  5   sexo_id                        35852 non-null  int64
#  6   Sexo                           35852 non-null  object
#  7   muerte_materna_id              35852 non-null  object
#  8   muerte_materna_clasificacion   35852 non-null  object
#  9   grupo_edad                     35852 non-null  object
#  10  cantidad                       35852 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 3.3+ MB
# None
#
# Información de df2_ped:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3421 entries, 8 to 80074
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   anio                           3421 non-null   int64
#  1   jurisdiccion_de_residencia_id  3421 non-null   int64
#  2   provincia_nombre               3421 non-null   object
#  3   cie10_causa_id                 3421 non-null   object
#  4   causa_defuncion                3421 non-null   object
#  5   sexo_id                        3421 non-null   int64
#  6   Sexo                           3421 non-null   object
#  7   muerte_materna_id              3421 non-null   object
#  8   muerte_materna_clasificacion   3421 non-null   object
#  9   grupo_edad                     3421 non-null   object
#  10  cantidad                       3421 non-null   int64
# dtypes: int64(4), object(7)
# memory usage: 320.7+ KB
# None

# %%
# Para df2_adulto
muertes_por_provincia_adulto = df2_adulto.groupby('provincia_nombre')['cantidad'].sum().reset_index()

# Para df2_ped
muertes_por_provincia_ped = df2_ped.groupby('provincia_nombre')['cantidad'].sum().reset_index()

# Mostrar los resultados
print("Muertes por provincia en df2_adulto:")
print(muertes_por_provincia_adulto)

print("\nMuertes por provincia en df2_ped:")
print(muertes_por_provincia_ped)
# Out:
# Muertes por provincia en df2_adulto:
#                                      provincia_nombre  cantidad
# 0                                        Buenos Aires    131377
# 1                                           Catamarca      2328
# 2                                               Chaco      7472
# 3                                              Chubut      3144
# 4                     Ciudad Autónoma de Buenos Aires     29852
# 5                                          Corrientes      6892
# 6                                             Córdoba     28907
# 7                                          Entre Ríos      9919
# 8                                             Formosa      3357
# 9                                               Jujuy      4155
# 10                                           La Pampa      2319
# 11                                           La Rioja      2129
# 12                                            Mendoza     13287
# 13                                           Misiones      6682
# 14                                            Neuquén      3214
# 15                                          Río Negro      4239
# 16                                              Salta      7241
# 17                                           San Juan      4802
# 18                                           San Luis      3118
# 19                                         Santa Cruz      1408
# 20                                           Santa Fe     28445
# 21                                Santiago del Estero      5815
# 22  Tierra del Fuego, Antártida e Islas del Atlánt...       501
# 23                                            Tucumán     10588
#
# Muertes por provincia en df2_ped:
#                                      provincia_nombre  cantidad
# 0                                        Buenos Aires      2762
# 1                                           Catamarca        78
# 2                                               Chaco       347
# 3                                              Chubut        78
# 4                     Ciudad Autónoma de Buenos Aires       288
# 5                                          Corrientes       276
# 6                                             Córdoba       522
# 7                                          Entre Ríos       250
# 8                                             Formosa       189
# 9                                               Jujuy       149
# 10                                           La Pampa        53
# 11                                           La Rioja        73
# 12                                            Mendoza       304
# 13                                           Misiones       314
# 14                                            Neuquén        77
# 15                                          Río Negro       106
# 16                                              Salta       315
# 17                                           San Juan       148
# 18                                           San Luis        77
# 19                                         Santa Cruz        39
# 20                                           Santa Fe       507
# 21                                Santiago del Estero       180
# 22  Tierra del Fuego, Antártida e Islas del Atlánt...        24
# 23                                            Tucumán       401

# %%
# Convertir nombres de provincia a mayúsculas en df2_adulto
muertes_por_provincia_adulto['provincia_nombre'] = muertes_por_provincia_adulto['provincia_nombre'].str.upper()

# Convertir nombres de provincia a mayúsculas en df2_ped
muertes_por_provincia_ped['provincia_nombre'] = muertes_por_provincia_ped['provincia_nombre'].str.upper()

# %%
# Calcular la tasa de mortalidad por provincia en adultos
muertes_por_provincia_adulto['Tasa de Mortalidad Adultos'] = muertes_por_provincia_adulto['cantidad'] / df_poblacion['Población 2019'] * 1000000

# Calcular la tasa de mortalidad por provincia en pediatría
muertes_por_provincia_ped['Tasa de Mortalidad Pediatría'] = muertes_por_provincia_ped['cantidad'] / df_poblacion['Población 2019'] * 1000000

# %%
# DataFrame de tasa de mortalidad por provincia en adultos
df_tasa_mortalidad_adulto = muertes_por_provincia_adulto[['provincia_nombre', 'Tasa de Mortalidad Adultos']]

# DataFrame de tasa de mortalidad por provincia en pediatría
df_tasa_mortalidad_ped = muertes_por_provincia_ped[['provincia_nombre', 'Tasa de Mortalidad Pediatría']]

# %%
# Ordenar los datos por la tasa de mortalidad para un gráfico más claro
df_tasa_mortalidad_ped_sorted = df_tasa_mortalidad_ped.sort_values(by='Tasa de Mortalidad Pediatría', ascending=False)

# Configurar el gráfico de barras horizontales
plt.figure(figsize=(10, 8))
plt.barh(df_tasa_mortalidad_ped_sorted['provincia_nombre'], df_tasa_mortalidad_ped_sorted['Tasa de Mortalidad Pediatría'], color='salmon')
plt.xlabel('Tasa de Mortalidad (por millón de habitantes)')
plt.title('Tasa de Mortalidad en Pediatría por Provincia en Argentina')
plt.gca().invert_yaxis()  # Invertir el eje y para que la provincia con mayor tasa esté arriba
plt.grid(axis='x', linestyle='--', alpha=0.7)

plt.show()

# %%
df_tasa_mortalidad_adulto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 2 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   provincia_nombre            24 non-null     object
#  1   Tasa de Mortalidad Adultos  24 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 512.0+ bytes

# %%
# Ordenar los datos por la tasa de mortalidad para un gráfico más claro
df_tasa_mortalidad_adulto_sorted = df_tasa_mortalidad_adulto.sort_values(by='Tasa de Mortalidad Adultos', ascending=False)

# Configurar el gráfico de barras horizontales
plt.figure(figsize=(10, 8))
plt.barh(df_tasa_mortalidad_adulto_sorted['provincia_nombre'], df_tasa_mortalidad_adulto_sorted['Tasa de Mortalidad Adultos'], color='salmon')
plt.xlabel('Tasa de Mortalidad (por millón de habitantes)')
plt.title('Tasa de Mortalidad en Adultos por Provincia en Argentina')
plt.gca().invert_yaxis()  # Invertir el eje y para que la provincia con mayor tasa esté arriba
plt.grid(axis='x', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# # Consultas y comentarios finales:
#
# * Todo el analisis esta hecho sobre el año 2019, este análisis de los datos solo es un punto de partida para nuestro obejtivo.
#
# * Vamos a agregar graficos de mapas para una mejor visualización y más clara.
#
# * Queremos hacer una clasificación por causas de muerte, o agrupación para un mejor analisis. Teniendo en cuenta por ejemplo el Código de causa de muerte según la Clasificación Internacional de Enfermedades (CIE-10).
